# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sdv
from sdv.evaluation.single_table import evaluate_quality
from sdv.single_table import CTGANSynthesizer
from sdv.single_table import TVAESynthesizer
from sdv.metadata import SingleTableMetadata
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, cross_validate
from sklearn.base import clone
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
import os
from catboost import CatBoostRegressor
from pytorch_tabnet.tab_model import TabNetRegressor

# %%
# Global variable
CURR_ACTIVITY = "mmo"
CURR_MUSCLE = "ta_r"
CURR_TYPE = "intensity"

# %%
# Read the data
all_data = pd.read_excel("Biopak data compiled final 1-70 v2.xlsx")

# Extract just JVA data
n_columns = len(all_data.columns)
step = 14
if CURR_ACTIVITY == "map":
    start = n_columns - step
elif CURR_ACTIVITY == "mle":
    start = n_columns - (step*2)
else:
    start = n_columns - (step*3)
data = all_data.iloc[:,start:start+step].copy()

# %%
# Visualize the data
data.head()
# Out:
#    JVA MMO left integral  JVA MMO left Integral <300Hz  \
# 0                   18.8                          18.1
# 1                   19.8                          17.4
# 2                   17.5                          16.2
# 3                   17.0                          15.3
# 4                   49.6                          46.9
#
#    JVA MMO left Integral >300Hz  JVA MMO left Integral ratio  \
# 0                           0.7                         0.04
# 1                           2.4                         0.14
# 2                           1.3                         0.08
# 3                           1.7                         0.11
# 4                           2.7                         0.06
#
#    JVA MMO left peak amplitude  JVA MMO left peak frequency  \
# 0                          2.7                           20
# 1                          1.2                           39
# 2                          1.8                           78
# 3                          1.8                           78
# 4                          6.2                           68
#
#    JVA MMO left median frequency  JVA MMO right integral  \
# 0                             54                    22.5
# 1                            112                    22.7
# 2                             88                    20.3
# 3                             98                    11.6
# 4                             73                    65.5
#
#    JVA MMO right Integral <300Hz  JVA MMO right Integral >300Hz  \
# 0                           21.6                            0.9
# 1                           20.2                            2.5
# 2                           18.1                            2.1
# 3                           10.5                            1.1
# 4                           62.0                            3.6
#
#    JVA MMO right Integral ratio  JVA MMO right peak amplitude  \
# 0                          0.04                           4.0
# 1                          0.12                           1.1
# 2                          0.12                           2.2
# 3                          0.10                           1.1
# 4                          0.06                           8.2
#
#    JVA MMO right peak frequency  JVA MMO right median frequency
# 0                            24                              49
# 1                            98                             127
# 2                            24                              73
# 3                            20                              83
# 4                            20                              88

# %%
def add_quotients(muscle, data):
    intensity_quotients = pd.read_csv(f"quotients/{muscle}/quotient_intensity.csv")
    duration_quotients = pd.read_csv(f"quotients/{muscle}/quotient_duration.csv")
    temp_data_intensity = intensity_quotients.copy()
    temp_data_duration = duration_quotients.copy()
    temp_data_intensity.columns = [f"{muscle}_intensity_" + name
                                for name in temp_data_intensity.columns]
    temp_data_duration.columns = [f"{muscle}_duration_" + name
                                for name in temp_data_duration.columns]
    
    indices_to_insert_nan = [1, 40, 42, 60]

    # Insert NaN values without replacing existing values
    for index in indices_to_insert_nan:
        temp_data_intensity = pd.concat([temp_data_intensity.iloc[:index],
                                        pd.DataFrame([[np.nan] * len(temp_data_intensity.columns)],
                                                    columns=temp_data_intensity.columns),
                                                    temp_data_intensity.iloc[index:]],
                                                    ignore_index=True).copy()
        temp_data_duration = pd.concat([temp_data_duration.iloc[:index],
                                        pd.DataFrame([[np.nan] * len(temp_data_duration.columns)],
                                                    columns=temp_data_duration.columns),
                                                    temp_data_duration.iloc[index:]],
                                                    ignore_index=True).copy()
        
    # Add quotients to JVA data
    new_data = pd.concat([data, temp_data_intensity], axis=1)
    new_data = pd.concat([new_data, temp_data_duration], axis=1)

    return new_data

# %%
# Data with quotient
new_data = add_quotients(CURR_ACTIVITY, data)
new_data = new_data.dropna().copy()

# %%
new_data.head()
# Out:
#    JVA MMO left integral  JVA MMO left Integral <300Hz  \
# 0                   18.8                          18.1
# 2                   17.5                          16.2
# 3                   17.0                          15.3
# 4                   49.6                          46.9
# 5                   10.4                           9.5
#
#    JVA MMO left Integral >300Hz  JVA MMO left Integral ratio  \
# 0                           0.7                         0.04
# 2                           1.3                         0.08
# 3                           1.7                         0.11
# 4                           2.7                         0.06
# 5                           0.9                         0.10
#
#    JVA MMO left peak amplitude  JVA MMO left peak frequency  \
# 0                          2.7                           20
# 2                          1.8                           78
# 3                          1.8                           78
# 4                          6.2                           68
# 5                          1.2                           20
#
#    JVA MMO left median frequency  JVA MMO right integral  \
# 0                             54                    22.5
# 2                             88                    20.3
# 3                             98                    11.6
# 4                             73                    65.5
# 5                             73                    17.7
#
#    JVA MMO right Integral <300Hz  JVA MMO right Integral >300Hz  ...  \
# 0                           21.6                            0.9  ...
# 2                           18.1                            2.1  ...
# 3                           10.5                            1.1  ...
# 4                           62.0                            3.6  ...
# 5                           16.5                            1.3  ...
#
#    mmo_intensity_mm_r  mmo_intensity_mm_l  mmo_intensity_da_r  \
# 0                0.18                0.19                0.18
# 2                0.10                0.10                0.11
# 3                0.17                0.18                0.18
# 4                0.12                0.13                0.13
# 5                0.11                0.11                0.10
#
#    mmo_intensity_da_l  mmo_duration_ta_r  mmo_duration_ta_l  \
# 0                0.21               9.47              25.17
# 2                0.09              74.83              78.83
# 3                0.17              16.70               3.50
# 4                0.12              30.87              17.67
# 5                0.13              24.87              11.67
#
#    mmo_duration_mm_r  mmo_duration_mm_l  mmo_duration_da_r  mmo_duration_da_l
# 0              73.17              94.00              87.92             137.67
# 2              87.67              10.00              92.58               9.00
# 3              47.00              67.83              14.75              68.83
# 4              32.83              53.67              28.92              54.67
# 5             157.33              59.67              53.58             103.33
#
# [5 rows x 26 columns]

# %%
# Function to remove features with 0 variance (constant value features)
def get_const_value_features_to_drop(df):
    return [e for e in df.columns if df[e].nunique() == 1]

def impute_and_remove_zero_var(features_ta_r):
    # Performing imputation to replace any NaN value in the dataset with the median of the feature
    imputer = SimpleImputer(strategy="median")
    features_ta_r_imputed = imputer.fit_transform(features_ta_r)
    features_ta_r_imputed_df = pd.DataFrame(features_ta_r_imputed,
                                            columns=features_ta_r.columns)

    # Remove zero variance features
    columns_to_remove = get_const_value_features_to_drop(features_ta_r_imputed_df)
    features_ta_r_imputed_df.drop(columns=columns_to_remove, inplace=True)

    return features_ta_r_imputed_df

imputed_data = impute_and_remove_zero_var(new_data)

# %%
def tune_tvae(features_ta_r_imputed_df, metadata):
    # Tuning a variational autoencoder
    tvae_scores = []
    embedding_dims = [128, 256]
    compress_dims = [128, 256]
    decompress_dims = [128, 256]

    for embedding_dim in embedding_dims:
        for compress_dim in compress_dims:
            for decompress_dim in decompress_dims:
                # Creating a Variational Autoencoder synthesizer
                tvae_synthesizer = TVAESynthesizer(metadata,
                                                embedding_dim=embedding_dim,
                                                compress_dims=(compress_dim,compress_dim),
                                                decompress_dims=(decompress_dim,decompress_dim),
                                                epochs=500)
                
                # Fitting the model
                tvae_synthesizer.fit(features_ta_r_imputed_df)
                
                # Generating synthetic data
                synthetic_data = tvae_synthesizer.sample(num_rows=200)

                # Evaluating synthetic data
                quality_report = evaluate_quality(
                    features_ta_r_imputed_df,
                    synthetic_data,
                    metadata,
                    verbose=False
                )

                tvae_scores.append((quality_report.get_score(), tvae_synthesizer))

    return tvae_scores

def tune_ctgan(features_ta_r_imputed_df, metadata):
    # Tuning a ctgan
    ctgan_scores = []
    embedding_dims = [256, 512]
    generator_dims = [256, 512]
    discriminator_dims = [128, 256]

    for embedding_dim in embedding_dims:
        for generator_dim in generator_dims:
            for discriminator_dim in discriminator_dims:
                # Creating a ctgan synthesizer
                ctgan_synthesizer = CTGANSynthesizer(metadata,
                                                    embedding_dim=embedding_dim,
                                                    generator_dim=(generator_dim,generator_dim),
                                                    discriminator_dim=(discriminator_dim,discriminator_dim),
                                                    epochs=500)
                
                # Fitting the model
                ctgan_synthesizer.fit(features_ta_r_imputed_df)
                
                # Generating synthetic data
                synthetic_data = ctgan_synthesizer.sample(num_rows=200)

                # Evaluating synthetic data
                quality_report = evaluate_quality(
                    features_ta_r_imputed_df,
                    synthetic_data,
                    metadata,
                    verbose=False
                )

                ctgan_scores.append((quality_report.get_score(), ctgan_synthesizer))

    return ctgan_scores

def run_augmentation_pipeline(features_ta_r_imputed_df):

    # Creating metadata object to get metadata about the original dataset of extracted features
    metadata = SingleTableMetadata()
    metadata.detect_from_dataframe(data=features_ta_r_imputed_df)

    # Get tvae and ctgan tuning results
    tvae_scores = tune_tvae(features_ta_r_imputed_df, metadata)
    ctgan_scores = tune_ctgan(features_ta_r_imputed_df, metadata)

    # Return scores
    return tvae_scores, ctgan_scores

tvae_scores, ctgan_scores = run_augmentation_pipeline(imputed_data)

# %%
# Creating a dataframe of tuning results for all
results = pd.DataFrame({
    "TVAE": sorted([each[0] for each in tvae_scores], reverse=True),
    "CTGAN": sorted([each[0] for each in ctgan_scores], reverse=True),
})
results
# Out:
#        TVAE     CTGAN
# 0  0.863684  0.782423
# 1  0.862057  0.778562
# 2  0.859711  0.750616
# 3  0.858614  0.748247
# 4  0.856019  0.725311
# 5  0.849368  0.718764
# 6  0.846309  0.711128
# 7  0.845648  0.683741

# %%
# obtaining the best models for each of the six muscles
best_tvae = sorted(tvae_scores, reverse=True)[0]

# Generating 2000 synthetic observations using the trained model
synthetic_data = best_tvae[1].sample(num_rows=2000, batch_size=100)
# Out:
# Sampling rows: 100%|██████████| 2000/2000 [00:00<00:00, 2195.28it/s]

# %%
len_columns = len(synthetic_data.columns)
columns = synthetic_data.columns[:len_columns-12]

# %%
# get response variable
y_train = synthetic_data[f"{CURR_ACTIVITY}_{CURR_TYPE}_{CURR_MUSCLE}"].copy()
y_test = imputed_data[f"{CURR_ACTIVITY}_{CURR_TYPE}_{CURR_MUSCLE}"].copy()
X_train = synthetic_data[columns]
X_test = imputed_data[columns]

# %% [markdown]
# #### Preprocessing

# %%
# Scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train).copy()
X_test_scaled = scaler.transform(X_test).copy()

# %% [markdown]
# #### Modelling

# %%
def get_lr_results(X_train, y_train):
    scores_lr = []
    # Create a CV instance
    cv_lr = KFold(n_splits=5, shuffle=True, random_state=42)
    for train, val in cv_lr.split(X_train, y_train):
        X_train_temp = X_train[train]
        X_val_temp = X_train[val]
        y_train_temp = y_train.values[train]
        y_val_temp = y_train.values[val]

        # Define model
        lr_model = LinearRegression()
        lr_model.fit(X_train_temp, y_train_temp)

        # Predictions
        predictions_train = lr_model.predict(X_train_temp)
        predictions_val = lr_model.predict(X_val_temp)

        train_rmse = np.sqrt(mean_squared_error(y_train_temp,
                                                predictions_train))
        val_rmse = np.sqrt(mean_squared_error(y_val_temp,
                                            predictions_val))
        scores_lr.append((val_rmse, train_rmse))

    # Compute average scores
    avg_val_rmse_lr = np.sum([each[0]
                             for each in scores_lr]) / len(scores_lr)
    avg_train_rmse_lr = np.sum([each[1]
                               for each in scores_lr]) / len(scores_lr)
    
    # Final fitted model
    final_lr = LinearRegression()
    final_lr.fit(X_train, y_train)

    return ((avg_train_rmse_lr,
             avg_val_rmse_lr),
             final_lr)

# %%
"""
The following function was taken from
https://xgboost.readthedocs.io/en/stable/python/sklearn_estimator.html
"""
def fit_and_score(estimator, X_train, X_test, y_train, y_test):
    """Fit the estimator on the train set and score it on both sets"""
    estimator.fit(X_train, y_train,
                  eval_set=[(X_test, y_test)], verbose=False)
    predictions_train = estimator.predict(X_train)
    predictions_test = estimator.predict(X_test)
    train_score = np.sqrt(mean_squared_error(y_train,
                                             predictions_train)) #estimator.score(X_train, y_train)
    test_score = np.sqrt(mean_squared_error(y_test,
                                            predictions_test)) #estimator.score(X_test, y_test)
    return estimator, train_score, test_score

def get_catboost_results(X_train, y_train):
    model = CatBoostRegressor(early_stopping_rounds=10)
    params = {
        'depth':range(3,6,2),
        'iterations':[100,500,1000],
        'learning_rate':[0.001,0.01,0.03,0.1], 
        # 'l2_leaf_reg': [1, 3, 5, 7, 9],
        # 'border_count':[32,5,10,20,50,100,200],
        # 'ctr_border_count':[50,5,10,20,100,200],
        # 'thread_count':4
    }
    results = model.grid_search(params,
                                X=X_train,
                                y=y_train,
                                cv=5,
                                refit=True,
                                partition_random_seed=42)
    
    # Refit using best params to create best model
    best_params = results["params"]
    best_model = CatBoostRegressor(**best_params)
    best_model.fit(X_train, y_train)

    # Get training and validation scores
    best_train_score = min(results['cv_results']['train-RMSE-mean'])
    best_val_score = min(results['cv_results']['test-RMSE-mean'])

    scores = {
        "Best Train RMSE": best_train_score,
        "Best Validation RMSE": best_val_score,
    }
    return scores, best_model

# %%
def get_xgboost_results(X_train, y_train):
    # Parameters to tune in the grid
    params_to_test = {
        'max_depth': range(3,10,2),
        'min_child_weight': range(1,6,2),
        'n_estimators': [100, 500, 1000],
        'learning_rate': [0.1, 0.01, 0.001]
    }

    # Performing gridSearch manually
    best_xgb_scores = None
    best_xgb_model = None
    curr_val_score = float('inf')
    for depth in params_to_test['max_depth']:
        for weight in params_to_test['min_child_weight']:
            for lr in params_to_test['learning_rate']:
                for estimator_count in params_to_test['n_estimators']:
                    # Create a CV instance
                    cv = KFold(n_splits=5, shuffle=True, random_state=42)

                    # XGBoost model
                    xgb_model = XGBRegressor(n_estimators=estimator_count, max_depth=depth,
                                            min_child_weight=weight, early_stopping_rounds=10,
                                            learning_rate=lr)

                    # Add cross validation results
                    total_train_score = 0
                    total_val_score = 0
                    for train, val in cv.split(X_train, y_train):
                        X_train_temp = X_train[train]
                        X_val_temp = X_train[val]
                        y_train_temp = y_train.values[train]
                        y_val_temp = y_train.values[val]

                        est, train_score, test_score = fit_and_score(
                            clone(xgb_model), X_train_temp,
                            X_val_temp, y_train_temp,
                            y_val_temp
                        )
                        total_train_score += train_score
                        total_val_score += test_score

                        avg_val_score = total_val_score / 5
                        if avg_val_score < curr_val_score:
                            curr_val_score = avg_val_score
                            best_xgb_scores = (total_train_score / 5, avg_val_score)
                            best_xgb_model = est

    # Determine best model (refitted)
    best_params = best_xgb_model.get_params()
    best_params["early_stopping_rounds"] = None
    best_model = XGBRegressor(**best_params)
    best_model.fit(X_train, y_train)
    return best_xgb_scores, best_model

# %%
def get_rf_results(X_train, y_train):
    params_to_test = {
        'max_depth': range(3,10,2),
        'n_estimators': [100, 500, 1000],
        'max_features': [1.0, 'sqrt', 'log2']
    }
    rf_grid = GridSearchCV(RandomForestRegressor(random_state=42),
                           params_to_test, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)

    # Best scores
    rf_grid.fit(X_train, y_train)
    rf_train_score = np.sqrt(
        -rf_grid.cv_results_['mean_train_score'][rf_grid.best_index_])
    rf_val_score = np.sqrt(-rf_grid.best_score_)

    # Best params
    best_params = rf_grid.best_params_
    best_model = RandomForestRegressor(**best_params)
    best_model.fit(X_train, y_train)

    return (rf_train_score, rf_val_score), best_model

# %%
def get_tabnet_results(X_train, y_train):
    reduced_X_train, X_val, reduced_y_train, y_val = \
        train_test_split(X_train, y_train)
    model = TabNetRegressor()
    model.fit(reduced_X_train,
              reduced_y_train,
              eval_metric="rmse",
              eval_set=[(X_val, y_val)])
    return model

# %%
tabnet_results = get_tabnet_results(X_train_scaled,
                                    y_train.values.reshape(-1,1))
# Out:
# /Users/tashrequehaq/miniconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/tashrequehaq/Documents/AHMS/For TMD Diagnostics [Task 3]/Code/task_4.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> tabnet_results = get_tabnet_results(X_train_scaled,
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a>                                     y_train.values.reshape(-1,1))
#
# /Users/tashrequehaq/Documents/AHMS/For TMD Diagnostics [Task 3]/Code/task_4.ipynb Cell 22 line 5
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> reduced_X_train, X_val, reduced_y_train, y_val = \
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a>     train_test_split(X_train, y_train)
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a> model = TabNetRegressor()
# ----> <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=4'>5</a> model.fit(reduced_X_train,
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a>           reduced_y_train,
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=6'>7</a>           eval_metric="rmse",
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=7'>8</a>           eval_set=[(X_val, y_val)])
#       <a href='vscode-notebook-cell:/Users/tashrequehaq/Documents/AHMS/For%20TMD%20Diagnostics%20%5BTask%203%5D/Code/task_4.ipynb#X53sZmlsZQ%3D%3D?line=8'>9</a> return model
#
# File ~/miniconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:242, in TabModel.fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, augmentations, compute_importance)
#     240     self._set_network()
#     241 self._update_network_params()
# --> 242 self._set_metrics(eval_metric, eval_names)
#     243 self._set_optimizer()
#     244 self._set_callbacks(callbacks)
#
# File ~/miniconda3/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:649, in TabModel._set_metrics(self, metrics, eval_names)
#     646 self._metric_container_dict = {}
#     647 for name in eval_names:
#     648     self._metric_container_dict.update(
# --> 649         {name: MetricContainer(metrics, prefix=f"{name}_")}
#     650     )
#     652 self._metrics = []
#     653 self._metrics_names = []
#
# File <string>:5, in __init__(self, metric_names, prefix)
#
# File ~/miniconda3/lib/python3.11/site-packages/pytorch_tabnet/metrics.py:138, in MetricContainer.__post_init__(self)
#     137 def __post_init__(self):
# --> 138     self.metrics = Metric.get_metrics_by_names(self.metric_names)
#     139     self.names = [self.prefix + name for name in self.metric_names]
#
# File ~/miniconda3/lib/python3.11/site-packages/pytorch_tabnet/metrics.py:195, in Metric.get_metrics_by_names(cls, names)
#     192 metrics = []
#     193 for name in names:
#     194     assert (
# --> 195         name in available_names
#     196     ), f"{name} is not available, choose in {available_names}"
#     197     idx = available_names.index(name)
#     198     metric = available_metrics[idx]()
#
# AssertionError: r is not available, choose in ['auc', 'accuracy', 'balanced_accuracy', 'logloss', 'mae', 'mse', 'rmsle', 'unsup_loss', 'unsup_loss_numpy', 'rmse']

# %%
catboost_results = get_catboost_results(X_train_scaled,
                                        y_train)
xgboost_results = get_xgboost_results(X_train_scaled,
                                      y_train)
# Out:
# 0:	learn: 0.1443760	test: 0.1417424	best: 0.1417424 (0)	total: 2.54ms	remaining: 2.54s
# 1:	learn: 0.1402942	test: 0.1376521	best: 0.1376521 (1)	total: 7.55ms	remaining: 3.77s
# 2:	learn: 0.1363700	test: 0.1337351	best: 0.1337351 (2)	total: 9.44ms	remaining: 3.14s
# 3:	learn: 0.1325437	test: 0.1299155	best: 0.1299155 (3)	total: 10.7ms	remaining: 2.67s
# 4:	learn: 0.1288395	test: 0.1261986	best: 0.1261986 (4)	total: 13.1ms	remaining: 2.6s
# 5:	learn: 0.1252603	test: 0.1226070	best: 0.1226070 (5)	total: 36.4ms	remaining: 6.02s
# 6:	learn: 0.1217800	test: 0.1191099	best: 0.1191099 (6)	total: 37ms	remaining: 5.25s
# 7:	learn: 0.1183961	test: 0.1157392	best: 0.1157392 (7)	total: 40ms	remaining: 4.96s
# 8:	learn: 0.1151409	test: 0.1124734	best: 0.1124734 (8)	total: 41.9ms	remaining: 4.61s
# 9:	learn: 0.1119800	test: 0.1093094	best: 0.1093094 (9)	total: 43.4ms	remaining: 4.29s
# 10:	learn: 0.1089319	test: 0.1062490	best: 0.1062490 (10)	total: 45ms	remaining: 4.05s
# 11:	learn: 0.1059874	test: 0.1032941	best: 0.1032941 (11)	total: 47.2ms	remaining: 3.88s
# 12:	learn: 0.1031215	test: 0.1004353	best: 0.1004353 (12)	total: 49.3ms	remaining: 3.74s
# 13:	learn: 0.1003531	test: 0.0976545	best: 0.0976545 (13)	total: 50.7ms	remaining: 3.57s
# 14:	learn: 0.0976924	test: 0.0949928	best: 0.0949928 (14)	total: 51.6ms	remaining: 3.39s
# 15:	learn: 0.0951067	test: 0.0923956	best: 0.0923956 (15)	total: 51.9ms	remaining: 3.19s
# 16:	learn: 0.0926010	test: 0.0898857	best: 0.0898857 (16)	total: 52.3ms	remaining: 3.03s
# 17:	learn: 0.0901754	test: 0.0874462	best: 0.0874462 (17)	total: 52.8ms	remaining: 2.88s
# 18:	learn: 0.0878413	test: 0.0851163	best: 0.0851163 (18)	total: 53.2ms	remaining: 2.75s
# 19:	learn: 0.0855789	test: 0.0828493	best: 0.0828493 (19)	total: 54.3ms	remaining: 2.66s
# 20:	learn: 0.0833999	test: 0.0806635	best: 0.0806635 (20)	total: 55.8ms	remaining: 2.6s
# 21:	learn: 0.0812924	test: 0.0785547	best: 0.0785547 (21)	total: 56.3ms	remaining: 2.5s
# 22:	learn: 0.0792577	test: 0.0765109	best: 0.0765109 (22)	total: 57.3ms	remaining: 2.43s
# 23:	learn: 0.0772974	test: 0.0745456	best: 0.0745456 (23)	total: 57.7ms	remaining: 2.35s
# 24:	learn: 0.0754042	test: 0.0726492	best: 0.0726492 (24)	total: 58.1ms	remaining: 2.27s
# 25:	learn: 0.0735725	test: 0.0708119	best: 0.0708119 (25)	total: 58.8ms	remaining: 2.2s
# 26:	learn: 0.0718074	test: 0.0690544	best: 0.0690544 (26)	total: 59.2ms	remaining: 2.13s
# 27:	learn: 0.0701072	test: 0.0673576	best: 0.0673576 (27)	total: 59.5ms	remaining: 2.07s
# 28:	learn: 0.0684701	test: 0.0657291	best: 0.0657291 (28)	total: 59.9ms	remaining: 2.01s
# 29:	learn: 0.0668867	test: 0.0641372	best: 0.0641372 (29)	total: 60.4ms	remaining: 1.95s
# 30:	learn: 0.0653456	test: 0.0625988	best: 0.0625988 (30)	total: 60.8ms	remaining: 1.9s
# 31:	learn: 0.0638762	test: 0.0611265	best: 0.0611265 (31)	total: 61.2ms	remaining: 1.85s
# 32:	learn: 0.0624548	test: 0.0597062	best: 0.0597062 (32)	total: 61.6ms	remaining: 1.8s
# 33:	learn: 0.0610891	test: 0.0583362	best: 0.0583362 (33)	total: 62.7ms	remaining: 1.78s
# 34:	learn: 0.0597783	test: 0.0570283	best: 0.0570283 (34)	total: 64ms	remaining: 1.76s
# 35:	learn: 0.0585138	test: 0.0557738	best: 0.0557738 (35)	total: 65.7ms	remaining: 1.76s
# 36:	learn: 0.0572903	test: 0.0545657	best: 0.0545657 (36)	total: 66.9ms	remaining: 1.74s
# 37:	learn: 0.0561214	test: 0.0534023	best: 0.0534023 (37)	total: 68.3ms	remaining: 1.73s
# 38:	learn: 0.0549973	test: 0.0522830	best: 0.0522830 (38)	total: 68.8ms	remaining: 1.69s
# 39:	learn: 0.0539127	test: 0.0512011	best: 0.0512011 (39)	total: 69.2ms	remaining: 1.66s
# 40:	learn: 0.0528807	test: 0.0501688	best: 0.0501688 (40)	total: 69.6ms	remaining: 1.63s
# 41:	learn: 0.0518887	test: 0.0491779	best: 0.0491779 (41)	total: 70ms	remaining: 1.6s
# 42:	learn: 0.0509364	test: 0.0482265	best: 0.0482265 (42)	total: 70.7ms	remaining: 1.57s
# 43:	learn: 0.0500249	test: 0.0473168	best: 0.0473168 (43)	total: 72.6ms	remaining: 1.58s
# 44:	learn: 0.0491500	test: 0.0464431	best: 0.0464431 (44)	total: 74ms	remaining: 1.57s
# 45:	learn: 0.0483107	test: 0.0456074	best: 0.0456074 (45)	total: 75.5ms	remaining: 1.57s
# 46:	learn: 0.0475061	test: 0.0448084	best: 0.0448084 (46)	total: 76.7ms	remaining: 1.55s
# 47:	learn: 0.0467134	test: 0.0440356	best: 0.0440356 (47)	total: 77.4ms	remaining: 1.53s
# 48:	learn: 0.0459590	test: 0.0432906	best: 0.0432906 (48)	total: 77.7ms	remaining: 1.51s
# 49:	learn: 0.0452449	test: 0.0425911	best: 0.0425911 (49)	total: 78ms	remaining: 1.48s
# 50:	learn: 0.0445573	test: 0.0419164	best: 0.0419164 (50)	total: 78.3ms	remaining: 1.46s
# 51:	learn: 0.0439135	test: 0.0412819	best: 0.0412819 (51)	total: 78.8ms	remaining: 1.44s
# 52:	learn: 0.0432802	test: 0.0406702	best: 0.0406702 (52)	total: 80.8ms	remaining: 1.44s
# 53:	learn: 0.0426937	test: 0.0400919	best: 0.0400919 (53)	total: 81.2ms	remaining: 1.42s
# 54:	learn: 0.0421330	test: 0.0395466	best: 0.0395466 (54)	total: 82.3ms	remaining: 1.41s
# 55:	learn: 0.0415821	test: 0.0390105	best: 0.0390105 (55)	total: 82.7ms	remaining: 1.39s
# 56:	learn: 0.0410640	test: 0.0385145	best: 0.0385145 (56)	total: 83.2ms	remaining: 1.38s
# 57:	learn: 0.0405585	test: 0.0380287	best: 0.0380287 (57)	total: 83.6ms	remaining: 1.36s
# 58:	learn: 0.0400892	test: 0.0375798	best: 0.0375798 (58)	total: 84.1ms	remaining: 1.34s
# 59:	learn: 0.0396327	test: 0.0371476	best: 0.0371476 (59)	total: 84.5ms	remaining: 1.32s
# 60:	learn: 0.0392114	test: 0.0367417	best: 0.0367417 (60)	total: 85.1ms	remaining: 1.31s
# 61:	learn: 0.0388063	test: 0.0363557	best: 0.0363557 (61)	total: 85.6ms	remaining: 1.29s
# 62:	learn: 0.0384234	test: 0.0359899	best: 0.0359899 (62)	total: 86ms	remaining: 1.28s
# 63:	learn: 0.0380628	test: 0.0356454	best: 0.0356454 (63)	total: 86.5ms	remaining: 1.26s
# 64:	learn: 0.0377169	test: 0.0353158	best: 0.0353158 (64)	total: 87ms	remaining: 1.25s
# 65:	learn: 0.0373888	test: 0.0350142	best: 0.0350142 (65)	total: 88.4ms	remaining: 1.25s
# 66:	learn: 0.0370762	test: 0.0347221	best: 0.0347221 (66)	total: 89.5ms	remaining: 1.25s
# 67:	learn: 0.0367800	test: 0.0344467	best: 0.0344467 (67)	total: 89.9ms	remaining: 1.23s
# 68:	learn: 0.0365013	test: 0.0341860	best: 0.0341860 (68)	total: 90.2ms	remaining: 1.22s
# 69:	learn: 0.0362285	test: 0.0339321	best: 0.0339321 (69)	total: 91.4ms	remaining: 1.21s
# 70:	learn: 0.0359777	test: 0.0336989	best: 0.0336989 (70)	total: 93ms	remaining: 1.22s
# 71:	learn: 0.0357210	test: 0.0334576	best: 0.0334576 (71)	total: 93.7ms	remaining: 1.21s
# 72:	learn: 0.0354836	test: 0.0332354	best: 0.0332354 (72)	total: 94.2ms	remaining: 1.2s
# 73:	learn: 0.0352660	test: 0.0330341	best: 0.0330341 (73)	total: 94.6ms	remaining: 1.18s
# 74:	learn: 0.0350610	test: 0.0328480	best: 0.0328480 (74)	total: 95.1ms	remaining: 1.17s
# 75:	learn: 0.0348675	test: 0.0326721	best: 0.0326721 (75)	total: 96.5ms	remaining: 1.17s
# 76:	learn: 0.0346626	test: 0.0324990	best: 0.0324990 (76)	total: 97.4ms	remaining: 1.17s
# 77:	learn: 0.0344859	test: 0.0323421	best: 0.0323421 (77)	total: 97.7ms	remaining: 1.16s
# 78:	learn: 0.0343142	test: 0.0321917	best: 0.0321917 (78)	total: 98.7ms	remaining: 1.15s
# 79:	learn: 0.0341559	test: 0.0320563	best: 0.0320563 (79)	total: 99.7ms	remaining: 1.15s
# 80:	learn: 0.0339902	test: 0.0319262	best: 0.0319262 (80)	total: 100ms	remaining: 1.14s
# 81:	learn: 0.0338445	test: 0.0318020	best: 0.0318020 (81)	total: 101ms	remaining: 1.13s
# 82:	learn: 0.0337091	test: 0.0316893	best: 0.0316893 (82)	total: 101ms	remaining: 1.11s
# 83:	learn: 0.0335692	test: 0.0315687	best: 0.0315687 (83)	total: 101ms	remaining: 1.1s
# 84:	learn: 0.0334469	test: 0.0314661	best: 0.0314661 (84)	total: 101ms	remaining: 1.09s
# 85:	learn: 0.0333243	test: 0.0313670	best: 0.0313670 (85)	total: 102ms	remaining: 1.08s
# 86:	learn: 0.0332135	test: 0.0312770	best: 0.0312770 (86)	total: 102ms	remaining: 1.07s
# 87:	learn: 0.0331047	test: 0.0311874	best: 0.0311874 (87)	total: 103ms	remaining: 1.06s
# 88:	learn: 0.0330079	test: 0.0311071	best: 0.0311071 (88)	total: 103ms	remaining: 1.06s
# 89:	learn: 0.0329041	test: 0.0310322	best: 0.0310322 (89)	total: 104ms	remaining: 1.05s
# 90:	learn: 0.0328092	test: 0.0309601	best: 0.0309601 (90)	total: 106ms	remaining: 1.05s
# 91:	learn: 0.0327211	test: 0.0308906	best: 0.0308906 (91)	total: 106ms	remaining: 1.05s
# 92:	learn: 0.0326334	test: 0.0308241	best: 0.0308241 (92)	total: 106ms	remaining: 1.04s
# 93:	learn: 0.0325571	test: 0.0307662	best: 0.0307662 (93)	total: 107ms	remaining: 1.03s
# 94:	learn: 0.0324909	test: 0.0307143	best: 0.0307143 (94)	total: 107ms	remaining: 1.02s
# 95:	learn: 0.0324156	test: 0.0306558	best: 0.0306558 (95)	total: 108ms	remaining: 1.01s
# 96:	learn: 0.0323437	test: 0.0306055	best: 0.0306055 (96)	total: 108ms	remaining: 1.01s
# 97:	learn: 0.0322870	test: 0.0305614	best: 0.0305614 (97)	total: 108ms	remaining: 998ms
# 98:	learn: 0.0322248	test: 0.0305226	best: 0.0305226 (98)	total: 109ms	remaining: 990ms
# 99:	learn: 0.0321687	test: 0.0304806	best: 0.0304806 (99)	total: 109ms	remaining: 983ms
# 100:	learn: 0.0321107	test: 0.0304391	best: 0.0304391 (100)	total: 110ms	remaining: 975ms
# 101:	learn: 0.0320534	test: 0.0304008	best: 0.0304008 (101)	total: 110ms	remaining: 967ms
# 102:	learn: 0.0320056	test: 0.0303682	best: 0.0303682 (102)	total: 110ms	remaining: 959ms
# 103:	learn: 0.0319613	test: 0.0303424	best: 0.0303424 (103)	total: 111ms	remaining: 953ms
# 104:	learn: 0.0319183	test: 0.0303104	best: 0.0303104 (104)	total: 111ms	remaining: 946ms
# 105:	learn: 0.0318671	test: 0.0302747	best: 0.0302747 (105)	total: 112ms	remaining: 943ms
# 106:	learn: 0.0318301	test: 0.0302540	best: 0.0302540 (106)	total: 113ms	remaining: 945ms
# 107:	learn: 0.0317932	test: 0.0302342	best: 0.0302342 (107)	total: 115ms	remaining: 951ms
# 108:	learn: 0.0317490	test: 0.0302074	best: 0.0302074 (108)	total: 116ms	remaining: 949ms
# 109:	learn: 0.0317045	test: 0.0301807	best: 0.0301807 (109)	total: 116ms	remaining: 943ms
# 110:	learn: 0.0316628	test: 0.0301616	best: 0.0301616 (110)	total: 117ms	remaining: 937ms
# 111:	learn: 0.0316309	test: 0.0301439	best: 0.0301439 (111)	total: 117ms	remaining: 931ms
# 112:	learn: 0.0316004	test: 0.0301271	best: 0.0301271 (112)	total: 118ms	remaining: 925ms
# 113:	learn: 0.0315736	test: 0.0301139	best: 0.0301139 (113)	total: 118ms	remaining: 918ms
# 114:	learn: 0.0315413	test: 0.0301004	best: 0.0301004 (114)	total: 118ms	remaining: 912ms
# 115:	learn: 0.0315082	test: 0.0300871	best: 0.0300871 (115)	total: 119ms	remaining: 905ms
# 116:	learn: 0.0314891	test: 0.0300775	best: 0.0300775 (116)	total: 119ms	remaining: 900ms
# 117:	learn: 0.0314555	test: 0.0300595	best: 0.0300595 (117)	total: 121ms	remaining: 906ms
# 118:	learn: 0.0314242	test: 0.0300510	best: 0.0300510 (118)	total: 122ms	remaining: 902ms
# 119:	learn: 0.0313936	test: 0.0300391	best: 0.0300391 (119)	total: 122ms	remaining: 896ms
# 120:	learn: 0.0313758	test: 0.0300271	best: 0.0300271 (120)	total: 122ms	remaining: 890ms
# 121:	learn: 0.0313605	test: 0.0300201	best: 0.0300201 (121)	total: 123ms	remaining: 885ms
# 122:	learn: 0.0313328	test: 0.0300061	best: 0.0300061 (122)	total: 123ms	remaining: 879ms
# 123:	learn: 0.0313108	test: 0.0299982	best: 0.0299982 (123)	total: 124ms	remaining: 873ms
# 124:	learn: 0.0312897	test: 0.0299987	best: 0.0299982 (123)	total: 124ms	remaining: 868ms
# 125:	learn: 0.0312755	test: 0.0299975	best: 0.0299975 (125)	total: 124ms	remaining: 862ms
# 126:	learn: 0.0312577	test: 0.0300001	best: 0.0299975 (125)	total: 125ms	remaining: 857ms
# 127:	learn: 0.0312266	test: 0.0299911	best: 0.0299911 (127)	total: 126ms	remaining: 856ms
# 128:	learn: 0.0311982	test: 0.0299802	best: 0.0299802 (128)	total: 126ms	remaining: 851ms
# 129:	learn: 0.0311796	test: 0.0299876	best: 0.0299802 (128)	total: 127ms	remaining: 847ms
# 130:	learn: 0.0311559	test: 0.0299800	best: 0.0299800 (130)	total: 127ms	remaining: 843ms
# 131:	learn: 0.0311330	test: 0.0299738	best: 0.0299738 (131)	total: 128ms	remaining: 840ms
# 132:	learn: 0.0311162	test: 0.0299663	best: 0.0299663 (132)	total: 129ms	remaining: 841ms
# 133:	learn: 0.0310986	test: 0.0299547	best: 0.0299547 (133)	total: 131ms	remaining: 843ms
# 134:	learn: 0.0310850	test: 0.0299487	best: 0.0299487 (134)	total: 131ms	remaining: 838ms
# 135:	learn: 0.0310694	test: 0.0299456	best: 0.0299456 (135)	total: 131ms	remaining: 833ms
# 136:	learn: 0.0310550	test: 0.0299421	best: 0.0299421 (136)	total: 131ms	remaining: 828ms
# 137:	learn: 0.0310412	test: 0.0299407	best: 0.0299407 (137)	total: 132ms	remaining: 823ms
# 138:	learn: 0.0310251	test: 0.0299356	best: 0.0299356 (138)	total: 132ms	remaining: 818ms
# 139:	learn: 0.0310104	test: 0.0299373	best: 0.0299356 (138)	total: 132ms	remaining: 813ms
# 140:	learn: 0.0309958	test: 0.0299352	best: 0.0299352 (140)	total: 133ms	remaining: 808ms
# 141:	learn: 0.0309783	test: 0.0299291	best: 0.0299291 (141)	total: 133ms	remaining: 804ms
# 142:	learn: 0.0309719	test: 0.0299289	best: 0.0299289 (142)	total: 133ms	remaining: 799ms
# 143:	learn: 0.0309509	test: 0.0299256	best: 0.0299256 (143)	total: 134ms	remaining: 794ms
# 144:	learn: 0.0309376	test: 0.0299144	best: 0.0299144 (144)	total: 134ms	remaining: 790ms
# 145:	learn: 0.0309225	test: 0.0299164	best: 0.0299144 (144)	total: 134ms	remaining: 785ms
# 146:	learn: 0.0309106	test: 0.0299153	best: 0.0299144 (144)	total: 135ms	remaining: 781ms
# 147:	learn: 0.0308955	test: 0.0299149	best: 0.0299144 (144)	total: 135ms	remaining: 776ms
# 148:	learn: 0.0308856	test: 0.0299067	best: 0.0299067 (148)	total: 135ms	remaining: 772ms
# 149:	learn: 0.0308697	test: 0.0299094	best: 0.0299067 (148)	total: 135ms	remaining: 768ms
# 150:	learn: 0.0308652	test: 0.0299106	best: 0.0299067 (148)	total: 136ms	remaining: 767ms
# 151:	learn: 0.0308502	test: 0.0299118	best: 0.0299067 (148)	total: 137ms	remaining: 766ms
# 152:	learn: 0.0308368	test: 0.0299127	best: 0.0299067 (148)	total: 138ms	remaining: 766ms
# 153:	learn: 0.0308222	test: 0.0299179	best: 0.0299067 (148)	total: 139ms	remaining: 763ms
# 154:	learn: 0.0308067	test: 0.0299100	best: 0.0299067 (148)	total: 139ms	remaining: 760ms
# 155:	learn: 0.0307940	test: 0.0299093	best: 0.0299067 (148)	total: 140ms	remaining: 756ms
# 156:	learn: 0.0307853	test: 0.0299053	best: 0.0299053 (156)	total: 140ms	remaining: 752ms
# 157:	learn: 0.0307709	test: 0.0299018	best: 0.0299018 (157)	total: 140ms	remaining: 748ms
# 158:	learn: 0.0307492	test: 0.0298857	best: 0.0298857 (158)	total: 141ms	remaining: 744ms
# 159:	learn: 0.0307434	test: 0.0298944	best: 0.0298857 (158)	total: 141ms	remaining: 740ms
# 160:	learn: 0.0307265	test: 0.0298863	best: 0.0298857 (158)	total: 141ms	remaining: 736ms
# 161:	learn: 0.0307140	test: 0.0298876	best: 0.0298857 (158)	total: 142ms	remaining: 732ms
# 162:	learn: 0.0307022	test: 0.0298869	best: 0.0298857 (158)	total: 142ms	remaining: 728ms
# 163:	learn: 0.0306907	test: 0.0298865	best: 0.0298857 (158)	total: 142ms	remaining: 725ms
# 164:	learn: 0.0306833	test: 0.0298859	best: 0.0298857 (158)	total: 142ms	remaining: 721ms
# 165:	learn: 0.0306723	test: 0.0298894	best: 0.0298857 (158)	total: 143ms	remaining: 717ms
# 166:	learn: 0.0306591	test: 0.0298861	best: 0.0298857 (158)	total: 143ms	remaining: 714ms
# 167:	learn: 0.0306504	test: 0.0298871	best: 0.0298857 (158)	total: 144ms	remaining: 711ms
# 168:	learn: 0.0306392	test: 0.0298865	best: 0.0298857 (158)	total: 145ms	remaining: 713ms
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.02988570465
# bestIteration = 158
#
# 0:	loss: 0.0298857	best: 0.0298857 (0)	total: 158ms	remaining: 158ms
# 0:	learn: 0.1444220	test: 0.1418304	best: 0.1418304 (0)	total: 1.84ms	remaining: 1.84s
# 1:	learn: 0.1404126	test: 0.1378496	best: 0.1378496 (1)	total: 2.58ms	remaining: 1.28s
# 2:	learn: 0.1365110	test: 0.1339341	best: 0.1339341 (2)	total: 3.42ms	remaining: 1.14s
# 3:	learn: 0.1326971	test: 0.1301087	best: 0.1301087 (3)	total: 5.49ms	remaining: 1.36s
# 4:	learn: 0.1290441	test: 0.1264561	best: 0.1264561 (4)	total: 6.28ms	remaining: 1.25s
# 5:	learn: 0.1255283	test: 0.1229517	best: 0.1229517 (5)	total: 6.85ms	remaining: 1.13s
# 6:	learn: 0.1220755	test: 0.1194837	best: 0.1194837 (6)	total: 7.29ms	remaining: 1.03s
# 7:	learn: 0.1187575	test: 0.1161565	best: 0.1161565 (7)	total: 7.81ms	remaining: 969ms
# 8:	learn: 0.1155177	test: 0.1129208	best: 0.1129208 (8)	total: 8.36ms	remaining: 920ms
# 9:	learn: 0.1124274	test: 0.1098121	best: 0.1098121 (9)	total: 9.6ms	remaining: 950ms
# 10:	learn: 0.1093951	test: 0.1067801	best: 0.1067801 (10)	total: 10.4ms	remaining: 939ms
# 11:	learn: 0.1064482	test: 0.1038238	best: 0.1038238 (11)	total: 11.2ms	remaining: 925ms
# 12:	learn: 0.1035841	test: 0.1009829	best: 0.1009829 (12)	total: 12.8ms	remaining: 974ms
# 13:	learn: 0.1008390	test: 0.0982390	best: 0.0982390 (13)	total: 13.6ms	remaining: 958ms
# 14:	learn: 0.0981615	test: 0.0955527	best: 0.0955527 (14)	total: 14.7ms	remaining: 964ms
# 15:	learn: 0.0955935	test: 0.0929834	best: 0.0929834 (15)	total: 15.7ms	remaining: 966ms
# 16:	learn: 0.0930921	test: 0.0904828	best: 0.0904828 (16)	total: 17.8ms	remaining: 1.03s
# 17:	learn: 0.0906776	test: 0.0880634	best: 0.0880634 (17)	total: 18.4ms	remaining: 1s
# 18:	learn: 0.0883338	test: 0.0857158	best: 0.0857158 (18)	total: 19.1ms	remaining: 986ms
# 19:	learn: 0.0860809	test: 0.0834767	best: 0.0834767 (19)	total: 20.7ms	remaining: 1.01s
# 20:	learn: 0.0838853	test: 0.0812910	best: 0.0812910 (20)	total: 21.7ms	remaining: 1.01s
# 21:	learn: 0.0817712	test: 0.0791722	best: 0.0791722 (21)	total: 23.3ms	remaining: 1.03s
# 22:	learn: 0.0797527	test: 0.0771795	best: 0.0771795 (22)	total: 24.8ms	remaining: 1.05s
# 23:	learn: 0.0777923	test: 0.0752205	best: 0.0752205 (23)	total: 25.5ms	remaining: 1.04s
# 24:	learn: 0.0759243	test: 0.0733538	best: 0.0733538 (24)	total: 26.3ms	remaining: 1.02s
# 25:	learn: 0.0740770	test: 0.0715182	best: 0.0715182 (25)	total: 27ms	remaining: 1.01s
# 26:	learn: 0.0723024	test: 0.0697403	best: 0.0697403 (26)	total: 28.1ms	remaining: 1.01s
# 27:	learn: 0.0705868	test: 0.0680168	best: 0.0680168 (27)	total: 29.8ms	remaining: 1.03s
# 28:	learn: 0.0689484	test: 0.0664002	best: 0.0664002 (28)	total: 30.4ms	remaining: 1.02s
# 29:	learn: 0.0673674	test: 0.0648359	best: 0.0648359 (29)	total: 31.1ms	remaining: 1.01s
# 30:	learn: 0.0658228	test: 0.0632901	best: 0.0632901 (30)	total: 31.6ms	remaining: 989ms
# 31:	learn: 0.0643288	test: 0.0617927	best: 0.0617927 (31)	total: 32.4ms	remaining: 980ms
# 32:	learn: 0.0628970	test: 0.0603639	best: 0.0603639 (32)	total: 33.1ms	remaining: 969ms
# 33:	learn: 0.0615260	test: 0.0590163	best: 0.0590163 (33)	total: 33.6ms	remaining: 953ms
# 34:	learn: 0.0601848	test: 0.0576866	best: 0.0576866 (34)	total: 34.1ms	remaining: 939ms
# 35:	learn: 0.0588986	test: 0.0564017	best: 0.0564017 (35)	total: 34.6ms	remaining: 927ms
# 36:	learn: 0.0576695	test: 0.0551901	best: 0.0551901 (36)	total: 35.6ms	remaining: 926ms
# 37:	learn: 0.0564850	test: 0.0540298	best: 0.0540298 (37)	total: 37ms	remaining: 938ms
# 38:	learn: 0.0553457	test: 0.0529051	best: 0.0529051 (38)	total: 38.7ms	remaining: 953ms
# 39:	learn: 0.0542659	test: 0.0518403	best: 0.0518403 (39)	total: 39.9ms	remaining: 958ms
# 40:	learn: 0.0532116	test: 0.0507948	best: 0.0507948 (40)	total: 41.1ms	remaining: 961ms
# 41:	learn: 0.0521941	test: 0.0497907	best: 0.0497907 (41)	total: 41.6ms	remaining: 949ms
# 42:	learn: 0.0512280	test: 0.0488347	best: 0.0488347 (42)	total: 42.4ms	remaining: 944ms
# 43:	learn: 0.0502874	test: 0.0479100	best: 0.0479100 (43)	total: 44ms	remaining: 957ms
# 44:	learn: 0.0493984	test: 0.0470263	best: 0.0470263 (44)	total: 45.8ms	remaining: 973ms
# 45:	learn: 0.0485464	test: 0.0461857	best: 0.0461857 (45)	total: 47.2ms	remaining: 978ms
# 46:	learn: 0.0477216	test: 0.0453756	best: 0.0453756 (46)	total: 47.7ms	remaining: 967ms
# 47:	learn: 0.0469412	test: 0.0446011	best: 0.0446011 (47)	total: 48.4ms	remaining: 960ms
# 48:	learn: 0.0461841	test: 0.0438554	best: 0.0438554 (48)	total: 49.4ms	remaining: 960ms
# 49:	learn: 0.0454667	test: 0.0431518	best: 0.0431518 (49)	total: 50ms	remaining: 950ms
# 50:	learn: 0.0447644	test: 0.0424821	best: 0.0424821 (50)	total: 51.1ms	remaining: 952ms
# 51:	learn: 0.0441043	test: 0.0418311	best: 0.0418311 (51)	total: 53.1ms	remaining: 968ms
# 52:	learn: 0.0434599	test: 0.0412102	best: 0.0412102 (52)	total: 54.7ms	remaining: 977ms
# 53:	learn: 0.0428534	test: 0.0406274	best: 0.0406274 (53)	total: 55.6ms	remaining: 974ms
# 54:	learn: 0.0422770	test: 0.0400633	best: 0.0400633 (54)	total: 56.4ms	remaining: 968ms
# 55:	learn: 0.0417167	test: 0.0395189	best: 0.0395189 (55)	total: 58.4ms	remaining: 985ms
# 56:	learn: 0.0411957	test: 0.0390207	best: 0.0390207 (56)	total: 59.3ms	remaining: 982ms
# 57:	learn: 0.0406856	test: 0.0385294	best: 0.0385294 (57)	total: 62.2ms	remaining: 1.01s
# 58:	learn: 0.0402127	test: 0.0380762	best: 0.0380762 (58)	total: 65ms	remaining: 1.04s
# 59:	learn: 0.0397453	test: 0.0376266	best: 0.0376266 (59)	total: 67.4ms	remaining: 1.06s
# 60:	learn: 0.0393035	test: 0.0372045	best: 0.0372045 (60)	total: 71.2ms	remaining: 1.09s
# 61:	learn: 0.0388769	test: 0.0368049	best: 0.0368049 (61)	total: 72.5ms	remaining: 1.1s
# 62:	learn: 0.0384715	test: 0.0364240	best: 0.0364240 (62)	total: 74.6ms	remaining: 1.11s
# 63:	learn: 0.0380885	test: 0.0360675	best: 0.0360675 (63)	total: 77.7ms	remaining: 1.14s
# 64:	learn: 0.0377246	test: 0.0357349	best: 0.0357349 (64)	total: 80.7ms	remaining: 1.16s
# 65:	learn: 0.0373784	test: 0.0354104	best: 0.0354104 (65)	total: 82.3ms	remaining: 1.16s
# 66:	learn: 0.0370453	test: 0.0351035	best: 0.0351035 (66)	total: 82.8ms	remaining: 1.15s
# 67:	learn: 0.0367275	test: 0.0348220	best: 0.0348220 (67)	total: 83.4ms	remaining: 1.14s
# 68:	learn: 0.0364219	test: 0.0345491	best: 0.0345491 (68)	total: 84ms	remaining: 1.13s
# 69:	learn: 0.0361393	test: 0.0342862	best: 0.0342862 (69)	total: 85ms	remaining: 1.13s
# 70:	learn: 0.0358602	test: 0.0340297	best: 0.0340297 (70)	total: 87.4ms	remaining: 1.14s
# 71:	learn: 0.0355986	test: 0.0337959	best: 0.0337959 (71)	total: 89.3ms	remaining: 1.15s
# 72:	learn: 0.0353388	test: 0.0335627	best: 0.0335627 (72)	total: 90.4ms	remaining: 1.15s
# 73:	learn: 0.0351113	test: 0.0333534	best: 0.0333534 (73)	total: 91.1ms	remaining: 1.14s
# 74:	learn: 0.0348923	test: 0.0331542	best: 0.0331542 (74)	total: 91.7ms	remaining: 1.13s
# 75:	learn: 0.0346759	test: 0.0329665	best: 0.0329665 (75)	total: 92.3ms	remaining: 1.12s
# 76:	learn: 0.0344777	test: 0.0327943	best: 0.0327943 (76)	total: 93ms	remaining: 1.11s
# 77:	learn: 0.0342866	test: 0.0326388	best: 0.0326388 (77)	total: 95ms	remaining: 1.12s
# 78:	learn: 0.0341033	test: 0.0324891	best: 0.0324891 (78)	total: 98.5ms	remaining: 1.15s
# 79:	learn: 0.0339229	test: 0.0323466	best: 0.0323466 (79)	total: 99ms	remaining: 1.14s
# 80:	learn: 0.0337607	test: 0.0322034	best: 0.0322034 (80)	total: 100ms	remaining: 1.14s
# 81:	learn: 0.0335996	test: 0.0320678	best: 0.0320678 (81)	total: 101ms	remaining: 1.13s
# 82:	learn: 0.0334554	test: 0.0319440	best: 0.0319440 (82)	total: 103ms	remaining: 1.14s
# 83:	learn: 0.0333162	test: 0.0318310	best: 0.0318310 (83)	total: 105ms	remaining: 1.14s
# 84:	learn: 0.0331854	test: 0.0317313	best: 0.0317313 (84)	total: 105ms	remaining: 1.13s
# 85:	learn: 0.0330521	test: 0.0316192	best: 0.0316192 (85)	total: 107ms	remaining: 1.14s
# 86:	learn: 0.0329303	test: 0.0315203	best: 0.0315203 (86)	total: 108ms	remaining: 1.13s
# 87:	learn: 0.0328020	test: 0.0314206	best: 0.0314206 (87)	total: 109ms	remaining: 1.13s
# 88:	learn: 0.0326858	test: 0.0313278	best: 0.0313278 (88)	total: 110ms	remaining: 1.13s
# 89:	learn: 0.0325640	test: 0.0312419	best: 0.0312419 (89)	total: 111ms	remaining: 1.13s
# 90:	learn: 0.0324563	test: 0.0311576	best: 0.0311576 (90)	total: 112ms	remaining: 1.12s
# 91:	learn: 0.0323543	test: 0.0310840	best: 0.0310840 (91)	total: 113ms	remaining: 1.11s
# 92:	learn: 0.0322648	test: 0.0310163	best: 0.0310163 (92)	total: 114ms	remaining: 1.11s
# 93:	learn: 0.0321822	test: 0.0309653	best: 0.0309653 (93)	total: 115ms	remaining: 1.11s
# 94:	learn: 0.0320912	test: 0.0308958	best: 0.0308958 (94)	total: 116ms	remaining: 1.1s
# 95:	learn: 0.0320169	test: 0.0308388	best: 0.0308388 (95)	total: 116ms	remaining: 1.09s
# 96:	learn: 0.0319468	test: 0.0307850	best: 0.0307850 (96)	total: 117ms	remaining: 1.09s
# 97:	learn: 0.0318658	test: 0.0307366	best: 0.0307366 (97)	total: 118ms	remaining: 1.09s
# 98:	learn: 0.0318051	test: 0.0306931	best: 0.0306931 (98)	total: 120ms	remaining: 1.09s
# 99:	learn: 0.0317284	test: 0.0306554	best: 0.0306554 (99)	total: 122ms	remaining: 1.1s
# 100:	learn: 0.0316744	test: 0.0306166	best: 0.0306166 (100)	total: 123ms	remaining: 1.09s
# 101:	learn: 0.0316225	test: 0.0305758	best: 0.0305758 (101)	total: 125ms	remaining: 1.1s
# 102:	learn: 0.0315567	test: 0.0305392	best: 0.0305392 (102)	total: 127ms	remaining: 1.1s
# 103:	learn: 0.0314894	test: 0.0305059	best: 0.0305059 (103)	total: 128ms	remaining: 1.1s
# 104:	learn: 0.0314284	test: 0.0304715	best: 0.0304715 (104)	total: 129ms	remaining: 1.1s
# 105:	learn: 0.0313781	test: 0.0304404	best: 0.0304404 (105)	total: 130ms	remaining: 1.09s
# 106:	learn: 0.0313179	test: 0.0304151	best: 0.0304151 (106)	total: 132ms	remaining: 1.1s
# 107:	learn: 0.0312580	test: 0.0303855	best: 0.0303855 (107)	total: 132ms	remaining: 1.09s
# 108:	learn: 0.0312143	test: 0.0303634	best: 0.0303634 (108)	total: 133ms	remaining: 1.09s
# 109:	learn: 0.0311624	test: 0.0303386	best: 0.0303386 (109)	total: 134ms	remaining: 1.08s
# 110:	learn: 0.0311155	test: 0.0303157	best: 0.0303157 (110)	total: 135ms	remaining: 1.08s
# 111:	learn: 0.0310718	test: 0.0302899	best: 0.0302899 (111)	total: 137ms	remaining: 1.08s
# 112:	learn: 0.0310289	test: 0.0302646	best: 0.0302646 (112)	total: 137ms	remaining: 1.08s
# 113:	learn: 0.0309814	test: 0.0302609	best: 0.0302609 (113)	total: 138ms	remaining: 1.07s
# 114:	learn: 0.0309389	test: 0.0302395	best: 0.0302395 (114)	total: 138ms	remaining: 1.06s
# 115:	learn: 0.0309016	test: 0.0302111	best: 0.0302111 (115)	total: 139ms	remaining: 1.06s
# 116:	learn: 0.0308727	test: 0.0301958	best: 0.0301958 (116)	total: 140ms	remaining: 1.06s
# 117:	learn: 0.0308395	test: 0.0301782	best: 0.0301782 (117)	total: 141ms	remaining: 1.06s
# 118:	learn: 0.0308067	test: 0.0301652	best: 0.0301652 (118)	total: 143ms	remaining: 1.06s
# 119:	learn: 0.0307673	test: 0.0301512	best: 0.0301512 (119)	total: 145ms	remaining: 1.06s
# 120:	learn: 0.0307379	test: 0.0301395	best: 0.0301395 (120)	total: 145ms	remaining: 1.05s
# 121:	learn: 0.0307096	test: 0.0301307	best: 0.0301307 (121)	total: 146ms	remaining: 1.05s
# 122:	learn: 0.0306843	test: 0.0301064	best: 0.0301064 (122)	total: 147ms	remaining: 1.05s
# 123:	learn: 0.0306608	test: 0.0300970	best: 0.0300970 (123)	total: 148ms	remaining: 1.05s
# 124:	learn: 0.0306352	test: 0.0300882	best: 0.0300882 (124)	total: 149ms	remaining: 1.04s
# 125:	learn: 0.0305987	test: 0.0300751	best: 0.0300751 (125)	total: 150ms	remaining: 1.04s
# 126:	learn: 0.0305786	test: 0.0300711	best: 0.0300711 (126)	total: 152ms	remaining: 1.04s
# 127:	learn: 0.0305525	test: 0.0300574	best: 0.0300574 (127)	total: 153ms	remaining: 1.04s
# 128:	learn: 0.0305233	test: 0.0300503	best: 0.0300503 (128)	total: 154ms	remaining: 1.04s
# 129:	learn: 0.0305048	test: 0.0300496	best: 0.0300496 (129)	total: 155ms	remaining: 1.03s
# 130:	learn: 0.0304847	test: 0.0300400	best: 0.0300400 (130)	total: 156ms	remaining: 1.03s
# 131:	learn: 0.0304501	test: 0.0300456	best: 0.0300400 (130)	total: 157ms	remaining: 1.03s
# 132:	learn: 0.0304274	test: 0.0300317	best: 0.0300317 (132)	total: 158ms	remaining: 1.03s
# 133:	learn: 0.0304033	test: 0.0300262	best: 0.0300262 (133)	total: 159ms	remaining: 1.03s
# 134:	learn: 0.0303716	test: 0.0300207	best: 0.0300207 (134)	total: 161ms	remaining: 1.03s
# 135:	learn: 0.0303475	test: 0.0300224	best: 0.0300207 (134)	total: 162ms	remaining: 1.03s
# 136:	learn: 0.0303040	test: 0.0300137	best: 0.0300137 (136)	total: 163ms	remaining: 1.03s
# 137:	learn: 0.0302832	test: 0.0300131	best: 0.0300131 (137)	total: 164ms	remaining: 1.02s
# 138:	learn: 0.0302580	test: 0.0300110	best: 0.0300110 (138)	total: 164ms	remaining: 1.02s
# 139:	learn: 0.0302288	test: 0.0300036	best: 0.0300036 (139)	total: 165ms	remaining: 1.01s
# 140:	learn: 0.0302018	test: 0.0299979	best: 0.0299979 (140)	total: 166ms	remaining: 1.01s
# 141:	learn: 0.0301825	test: 0.0299989	best: 0.0299979 (140)	total: 168ms	remaining: 1.02s
# 142:	learn: 0.0301512	test: 0.0299992	best: 0.0299979 (140)	total: 170ms	remaining: 1.02s
# 143:	learn: 0.0301228	test: 0.0300000	best: 0.0299979 (140)	total: 171ms	remaining: 1.01s
# 144:	learn: 0.0300934	test: 0.0299886	best: 0.0299886 (144)	total: 171ms	remaining: 1.01s
# 145:	learn: 0.0300669	test: 0.0299891	best: 0.0299886 (144)	total: 172ms	remaining: 1s
# 146:	learn: 0.0300498	test: 0.0299840	best: 0.0299840 (146)	total: 173ms	remaining: 1s
# 147:	learn: 0.0300328	test: 0.0299841	best: 0.0299840 (146)	total: 173ms	remaining: 998ms
# 148:	learn: 0.0300238	test: 0.0299796	best: 0.0299796 (148)	total: 174ms	remaining: 995ms
# 149:	learn: 0.0300031	test: 0.0299733	best: 0.0299733 (149)	total: 175ms	remaining: 994ms
# 150:	learn: 0.0299815	test: 0.0299696	best: 0.0299696 (150)	total: 177ms	remaining: 994ms
# 151:	learn: 0.0299709	test: 0.0299723	best: 0.0299696 (150)	total: 178ms	remaining: 992ms
# 152:	learn: 0.0299579	test: 0.0299678	best: 0.0299678 (152)	total: 179ms	remaining: 989ms
# 153:	learn: 0.0299405	test: 0.0299609	best: 0.0299609 (153)	total: 179ms	remaining: 986ms
# 154:	learn: 0.0299245	test: 0.0299623	best: 0.0299609 (153)	total: 181ms	remaining: 984ms
# 155:	learn: 0.0299028	test: 0.0299634	best: 0.0299609 (153)	total: 181ms	remaining: 981ms
# 156:	learn: 0.0298799	test: 0.0299618	best: 0.0299609 (153)	total: 182ms	remaining: 977ms
# 157:	learn: 0.0298715	test: 0.0299599	best: 0.0299599 (157)	total: 184ms	remaining: 980ms
# 158:	learn: 0.0298601	test: 0.0299512	best: 0.0299512 (158)	total: 185ms	remaining: 979ms
# 159:	learn: 0.0298461	test: 0.0299419	best: 0.0299419 (159)	total: 186ms	remaining: 977ms
# 160:	learn: 0.0298221	test: 0.0299426	best: 0.0299419 (159)	total: 187ms	remaining: 976ms
# 161:	learn: 0.0298029	test: 0.0299410	best: 0.0299410 (161)	total: 188ms	remaining: 974ms
# 162:	learn: 0.0297778	test: 0.0299330	best: 0.0299330 (162)	total: 189ms	remaining: 971ms
# 163:	learn: 0.0297459	test: 0.0299358	best: 0.0299330 (162)	total: 190ms	remaining: 967ms
# 164:	learn: 0.0297314	test: 0.0299324	best: 0.0299324 (164)	total: 191ms	remaining: 968ms
# 165:	learn: 0.0297094	test: 0.0299226	best: 0.0299226 (165)	total: 192ms	remaining: 965ms
# 166:	learn: 0.0296968	test: 0.0299216	best: 0.0299216 (166)	total: 193ms	remaining: 962ms
# 167:	learn: 0.0296852	test: 0.0299214	best: 0.0299214 (167)	total: 194ms	remaining: 959ms
# 168:	learn: 0.0296704	test: 0.0299147	best: 0.0299147 (168)	total: 194ms	remaining: 955ms
# 169:	learn: 0.0296626	test: 0.0299132	best: 0.0299132 (169)	total: 195ms	remaining: 951ms
# 170:	learn: 0.0296409	test: 0.0299135	best: 0.0299132 (169)	total: 195ms	remaining: 947ms
# 171:	learn: 0.0296253	test: 0.0299159	best: 0.0299132 (169)	total: 196ms	remaining: 944ms
# 172:	learn: 0.0296181	test: 0.0299162	best: 0.0299132 (169)	total: 197ms	remaining: 941ms
# 173:	learn: 0.0295932	test: 0.0299218	best: 0.0299132 (169)	total: 198ms	remaining: 938ms
# 174:	learn: 0.0295869	test: 0.0299121	best: 0.0299121 (174)	total: 198ms	remaining: 935ms
# 175:	learn: 0.0295767	test: 0.0298991	best: 0.0298991 (175)	total: 200ms	remaining: 938ms
# 176:	learn: 0.0295641	test: 0.0298958	best: 0.0298958 (176)	total: 201ms	remaining: 934ms
# 177:	learn: 0.0295497	test: 0.0298861	best: 0.0298861 (177)	total: 201ms	remaining: 930ms
# 178:	learn: 0.0295350	test: 0.0298893	best: 0.0298861 (177)	total: 202ms	remaining: 928ms
# 179:	learn: 0.0295159	test: 0.0298957	best: 0.0298861 (177)	total: 204ms	remaining: 929ms
# 180:	learn: 0.0295086	test: 0.0298930	best: 0.0298861 (177)	total: 205ms	remaining: 927ms
# 181:	learn: 0.0294923	test: 0.0299006	best: 0.0298861 (177)	total: 206ms	remaining: 926ms
# 182:	learn: 0.0294770	test: 0.0299041	best: 0.0298861 (177)	total: 207ms	remaining: 923ms
# 183:	learn: 0.0294619	test: 0.0299052	best: 0.0298861 (177)	total: 209ms	remaining: 925ms
# 184:	learn: 0.0294464	test: 0.0299067	best: 0.0298861 (177)	total: 210ms	remaining: 926ms
# 185:	learn: 0.0294287	test: 0.0299105	best: 0.0298861 (177)	total: 211ms	remaining: 923ms
# 186:	learn: 0.0294026	test: 0.0299029	best: 0.0298861 (177)	total: 211ms	remaining: 919ms
# 187:	learn: 0.0293843	test: 0.0299082	best: 0.0298861 (177)	total: 212ms	remaining: 915ms
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.02988611235
# bestIteration = 177
#
# 1:	loss: 0.0298861	best: 0.0298857 (0)	total: 376ms	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
# 0:	learn: 0.1433024	test: 0.1461296	best: 0.1461296 (0)	total: 1.53ms	remaining: 1.53s
# 1:	learn: 0.1392552	test: 0.1420837	best: 0.1420837 (1)	total: 1.95ms	remaining: 974ms
# 2:	learn: 0.1353417	test: 0.1381798	best: 0.1381798 (2)	total: 2.38ms	remaining: 792ms
# 3:	learn: 0.1315618	test: 0.1344093	best: 0.1344093 (3)	total: 2.82ms	remaining: 702ms
# 4:	learn: 0.1278835	test: 0.1307429	best: 0.1307429 (4)	total: 3.26ms	remaining: 650ms
# 5:	learn: 0.1243121	test: 0.1271901	best: 0.1271901 (5)	total: 3.73ms	remaining: 619ms
# 6:	learn: 0.1208629	test: 0.1237451	best: 0.1237451 (6)	total: 6.35ms	remaining: 901ms
# 7:	learn: 0.1175165	test: 0.1204136	best: 0.1204136 (7)	total: 7.09ms	remaining: 879ms
# 8:	learn: 0.1142957	test: 0.1171988	best: 0.1171988 (8)	total: 7.41ms	remaining: 816ms
# 9:	learn: 0.1111648	test: 0.1140760	best: 0.1140760 (9)	total: 7.73ms	remaining: 765ms
# 10:	learn: 0.1081365	test: 0.1110600	best: 0.1110600 (10)	total: 8.04ms	remaining: 723ms
# 11:	learn: 0.1051833	test: 0.1081074	best: 0.1081074 (11)	total: 8.42ms	remaining: 693ms
# 12:	learn: 0.1023324	test: 0.1052692	best: 0.1052692 (12)	total: 8.86ms	remaining: 673ms
# 13:	learn: 0.0995833	test: 0.1025353	best: 0.1025353 (13)	total: 9.3ms	remaining: 655ms
# 14:	learn: 0.0969298	test: 0.0998849	best: 0.0998849 (14)	total: 9.61ms	remaining: 631ms
# 15:	learn: 0.0943513	test: 0.0973186	best: 0.0973186 (15)	total: 9.92ms	remaining: 610ms
# 16:	learn: 0.0918576	test: 0.0948440	best: 0.0948440 (16)	total: 10.3ms	remaining: 593ms
# 17:	learn: 0.0894459	test: 0.0924468	best: 0.0924468 (17)	total: 10.6ms	remaining: 576ms
# 18:	learn: 0.0871346	test: 0.0901512	best: 0.0901512 (18)	total: 10.9ms	remaining: 562ms
# 19:	learn: 0.0848763	test: 0.0879076	best: 0.0879076 (19)	total: 11.2ms	remaining: 548ms
# 20:	learn: 0.0826823	test: 0.0857286	best: 0.0857286 (20)	total: 11.5ms	remaining: 536ms
# 21:	learn: 0.0805809	test: 0.0836443	best: 0.0836443 (21)	total: 11.8ms	remaining: 525ms
# 22:	learn: 0.0785469	test: 0.0816256	best: 0.0816256 (22)	total: 12.1ms	remaining: 515ms
# 23:	learn: 0.0765971	test: 0.0796866	best: 0.0796866 (23)	total: 12.4ms	remaining: 506ms
# 24:	learn: 0.0747046	test: 0.0778100	best: 0.0778100 (24)	total: 14.2ms	remaining: 553ms
# 25:	learn: 0.0728790	test: 0.0759910	best: 0.0759910 (25)	total: 14.5ms	remaining: 545ms
# 26:	learn: 0.0711149	test: 0.0742375	best: 0.0742375 (26)	total: 14.8ms	remaining: 534ms
# 27:	learn: 0.0694149	test: 0.0725425	best: 0.0725425 (27)	total: 15.1ms	remaining: 525ms
# 28:	learn: 0.0677784	test: 0.0709166	best: 0.0709166 (28)	total: 15.4ms	remaining: 516ms
# 29:	learn: 0.0661852	test: 0.0693529	best: 0.0693529 (29)	total: 15.7ms	remaining: 508ms
# 30:	learn: 0.0646683	test: 0.0678467	best: 0.0678467 (30)	total: 16ms	remaining: 501ms
# 31:	learn: 0.0632068	test: 0.0663894	best: 0.0663894 (31)	total: 16.3ms	remaining: 494ms
# 32:	learn: 0.0617868	test: 0.0649806	best: 0.0649806 (32)	total: 16.9ms	remaining: 495ms
# 33:	learn: 0.0604266	test: 0.0636341	best: 0.0636341 (33)	total: 17.2ms	remaining: 490ms
# 34:	learn: 0.0591139	test: 0.0623329	best: 0.0623329 (34)	total: 17.6ms	remaining: 484ms
# 35:	learn: 0.0578500	test: 0.0610789	best: 0.0610789 (35)	total: 17.9ms	remaining: 479ms
# 36:	learn: 0.0566379	test: 0.0598719	best: 0.0598719 (36)	total: 18.2ms	remaining: 473ms
# 37:	learn: 0.0554740	test: 0.0587217	best: 0.0587217 (37)	total: 18.7ms	remaining: 474ms
# 38:	learn: 0.0543559	test: 0.0576057	best: 0.0576057 (38)	total: 19.1ms	remaining: 471ms
# 39:	learn: 0.0532771	test: 0.0565374	best: 0.0565374 (39)	total: 19.6ms	remaining: 470ms
# 40:	learn: 0.0522430	test: 0.0555199	best: 0.0555199 (40)	total: 20ms	remaining: 467ms
# 41:	learn: 0.0512518	test: 0.0545335	best: 0.0545335 (41)	total: 20.3ms	remaining: 463ms
# 42:	learn: 0.0502976	test: 0.0535810	best: 0.0535810 (42)	total: 20.9ms	remaining: 465ms
# 43:	learn: 0.0493823	test: 0.0526691	best: 0.0526691 (43)	total: 22.2ms	remaining: 482ms
# 44:	learn: 0.0485022	test: 0.0517935	best: 0.0517935 (44)	total: 22.5ms	remaining: 478ms
# 45:	learn: 0.0476625	test: 0.0509533	best: 0.0509533 (45)	total: 23.2ms	remaining: 481ms
# 46:	learn: 0.0468542	test: 0.0501456	best: 0.0501456 (46)	total: 23.7ms	remaining: 480ms
# 47:	learn: 0.0460839	test: 0.0493763	best: 0.0493763 (47)	total: 24.1ms	remaining: 478ms
# 48:	learn: 0.0453431	test: 0.0486387	best: 0.0486387 (48)	total: 25ms	remaining: 485ms
# 49:	learn: 0.0446368	test: 0.0479391	best: 0.0479391 (49)	total: 25.3ms	remaining: 481ms
# 50:	learn: 0.0439599	test: 0.0472671	best: 0.0472671 (50)	total: 25.6ms	remaining: 477ms
# 51:	learn: 0.0433178	test: 0.0466260	best: 0.0466260 (51)	total: 26ms	remaining: 473ms
# 52:	learn: 0.0426889	test: 0.0460050	best: 0.0460050 (52)	total: 26.3ms	remaining: 470ms
# 53:	learn: 0.0420999	test: 0.0454142	best: 0.0454142 (53)	total: 26.6ms	remaining: 466ms
# 54:	learn: 0.0415376	test: 0.0448554	best: 0.0448554 (54)	total: 26.9ms	remaining: 462ms
# 55:	learn: 0.0410021	test: 0.0443225	best: 0.0443225 (55)	total: 27.2ms	remaining: 459ms
# 56:	learn: 0.0404717	test: 0.0437981	best: 0.0437981 (56)	total: 27.5ms	remaining: 455ms
# 57:	learn: 0.0399623	test: 0.0432983	best: 0.0432983 (57)	total: 27.8ms	remaining: 452ms
# 58:	learn: 0.0394790	test: 0.0428241	best: 0.0428241 (58)	total: 28.1ms	remaining: 449ms
# 59:	learn: 0.0390293	test: 0.0423723	best: 0.0423723 (59)	total: 28.5ms	remaining: 447ms
# 60:	learn: 0.0386047	test: 0.0419468	best: 0.0419468 (60)	total: 29.3ms	remaining: 452ms
# 61:	learn: 0.0382036	test: 0.0415414	best: 0.0415414 (61)	total: 30.8ms	remaining: 467ms
# 62:	learn: 0.0378206	test: 0.0411555	best: 0.0411555 (62)	total: 31.6ms	remaining: 470ms
# 63:	learn: 0.0374562	test: 0.0407880	best: 0.0407880 (63)	total: 32.1ms	remaining: 469ms
# 64:	learn: 0.0371086	test: 0.0404350	best: 0.0404350 (64)	total: 32.4ms	remaining: 466ms
# 65:	learn: 0.0367613	test: 0.0400922	best: 0.0400922 (65)	total: 32.7ms	remaining: 463ms
# 66:	learn: 0.0364492	test: 0.0397737	best: 0.0397737 (66)	total: 33ms	remaining: 460ms
# 67:	learn: 0.0361266	test: 0.0394543	best: 0.0394543 (67)	total: 33.3ms	remaining: 457ms
# 68:	learn: 0.0358370	test: 0.0391588	best: 0.0391588 (68)	total: 33.8ms	remaining: 456ms
# 69:	learn: 0.0355691	test: 0.0388820	best: 0.0388820 (69)	total: 34.2ms	remaining: 454ms
# 70:	learn: 0.0352982	test: 0.0386146	best: 0.0386146 (70)	total: 34.5ms	remaining: 451ms
# 71:	learn: 0.0350574	test: 0.0383576	best: 0.0383576 (71)	total: 34.8ms	remaining: 449ms
# 72:	learn: 0.0348285	test: 0.0381223	best: 0.0381223 (72)	total: 35.1ms	remaining: 446ms
# 73:	learn: 0.0345942	test: 0.0378935	best: 0.0378935 (73)	total: 35.4ms	remaining: 443ms
# 74:	learn: 0.0343820	test: 0.0376741	best: 0.0376741 (74)	total: 35.7ms	remaining: 441ms
# 75:	learn: 0.0341834	test: 0.0374644	best: 0.0374644 (75)	total: 36.1ms	remaining: 439ms
# 76:	learn: 0.0339998	test: 0.0372722	best: 0.0372722 (76)	total: 36.4ms	remaining: 436ms
# 77:	learn: 0.0338087	test: 0.0370891	best: 0.0370891 (77)	total: 36.9ms	remaining: 436ms
# 78:	learn: 0.0336444	test: 0.0369154	best: 0.0369154 (78)	total: 38ms	remaining: 444ms
# 79:	learn: 0.0334725	test: 0.0367471	best: 0.0367471 (79)	total: 38.7ms	remaining: 445ms
# 80:	learn: 0.0333111	test: 0.0365873	best: 0.0365873 (80)	total: 39.7ms	remaining: 450ms
# 81:	learn: 0.0331549	test: 0.0364262	best: 0.0364262 (81)	total: 40.1ms	remaining: 449ms
# 82:	learn: 0.0330061	test: 0.0362810	best: 0.0362810 (82)	total: 40.7ms	remaining: 450ms
# 83:	learn: 0.0328736	test: 0.0361420	best: 0.0361420 (83)	total: 42.7ms	remaining: 465ms
# 84:	learn: 0.0327495	test: 0.0360044	best: 0.0360044 (84)	total: 43.5ms	remaining: 468ms
# 85:	learn: 0.0326342	test: 0.0358816	best: 0.0358816 (85)	total: 45ms	remaining: 478ms
# 86:	learn: 0.0325293	test: 0.0357667	best: 0.0357667 (86)	total: 46.8ms	remaining: 492ms
# 87:	learn: 0.0324095	test: 0.0356558	best: 0.0356558 (87)	total: 47.3ms	remaining: 490ms
# 88:	learn: 0.0323023	test: 0.0355433	best: 0.0355433 (88)	total: 47.8ms	remaining: 490ms
# 89:	learn: 0.0321989	test: 0.0354325	best: 0.0354325 (89)	total: 48.3ms	remaining: 489ms
# 90:	learn: 0.0321045	test: 0.0353369	best: 0.0353369 (90)	total: 48.7ms	remaining: 487ms
# 91:	learn: 0.0320203	test: 0.0352474	best: 0.0352474 (91)	total: 49ms	remaining: 484ms
# 92:	learn: 0.0319436	test: 0.0351582	best: 0.0351582 (92)	total: 49.3ms	remaining: 481ms
# 93:	learn: 0.0318585	test: 0.0350749	best: 0.0350749 (93)	total: 49.6ms	remaining: 478ms
# 94:	learn: 0.0317809	test: 0.0349943	best: 0.0349943 (94)	total: 49.9ms	remaining: 476ms
# 95:	learn: 0.0317079	test: 0.0349044	best: 0.0349044 (95)	total: 50.3ms	remaining: 473ms
# 96:	learn: 0.0316365	test: 0.0348381	best: 0.0348381 (96)	total: 50.6ms	remaining: 472ms
# 97:	learn: 0.0315729	test: 0.0347654	best: 0.0347654 (97)	total: 51.2ms	remaining: 471ms
# 98:	learn: 0.0315131	test: 0.0346874	best: 0.0346874 (98)	total: 51.5ms	remaining: 469ms
# 99:	learn: 0.0314621	test: 0.0346273	best: 0.0346273 (99)	total: 51.8ms	remaining: 466ms
# 100:	learn: 0.0313980	test: 0.0345640	best: 0.0345640 (100)	total: 52.1ms	remaining: 464ms
# 101:	learn: 0.0313419	test: 0.0345077	best: 0.0345077 (101)	total: 52.5ms	remaining: 462ms
# 102:	learn: 0.0312889	test: 0.0344557	best: 0.0344557 (102)	total: 52.9ms	remaining: 461ms
# 103:	learn: 0.0312468	test: 0.0344073	best: 0.0344073 (103)	total: 55.1ms	remaining: 475ms
# 104:	learn: 0.0311942	test: 0.0343612	best: 0.0343612 (104)	total: 56.1ms	remaining: 478ms
# 105:	learn: 0.0311408	test: 0.0343043	best: 0.0343043 (105)	total: 56.4ms	remaining: 476ms
# 106:	learn: 0.0310904	test: 0.0342549	best: 0.0342549 (106)	total: 56.8ms	remaining: 474ms
# 107:	learn: 0.0310484	test: 0.0342122	best: 0.0342122 (107)	total: 57.3ms	remaining: 473ms
# 108:	learn: 0.0310059	test: 0.0341645	best: 0.0341645 (108)	total: 57.7ms	remaining: 472ms
# 109:	learn: 0.0309621	test: 0.0341275	best: 0.0341275 (109)	total: 58.2ms	remaining: 471ms
# 110:	learn: 0.0309230	test: 0.0340925	best: 0.0340925 (110)	total: 58.6ms	remaining: 469ms
# 111:	learn: 0.0308815	test: 0.0340570	best: 0.0340570 (111)	total: 58.9ms	remaining: 467ms
# 112:	learn: 0.0308499	test: 0.0340257	best: 0.0340257 (112)	total: 59.3ms	remaining: 465ms
# 113:	learn: 0.0308209	test: 0.0339975	best: 0.0339975 (113)	total: 59.8ms	remaining: 465ms
# 114:	learn: 0.0307959	test: 0.0339641	best: 0.0339641 (114)	total: 60.2ms	remaining: 463ms
# 115:	learn: 0.0307636	test: 0.0339259	best: 0.0339259 (115)	total: 60.7ms	remaining: 462ms
# 116:	learn: 0.0307282	test: 0.0338968	best: 0.0338968 (116)	total: 61.4ms	remaining: 463ms
# 117:	learn: 0.0307003	test: 0.0338728	best: 0.0338728 (117)	total: 62.4ms	remaining: 466ms
# 118:	learn: 0.0306708	test: 0.0338438	best: 0.0338438 (118)	total: 62.9ms	remaining: 465ms
# 119:	learn: 0.0306366	test: 0.0338121	best: 0.0338121 (119)	total: 63.5ms	remaining: 466ms
# 120:	learn: 0.0306140	test: 0.0337847	best: 0.0337847 (120)	total: 64ms	remaining: 465ms
# 121:	learn: 0.0305896	test: 0.0337577	best: 0.0337577 (121)	total: 64.4ms	remaining: 464ms
# 122:	learn: 0.0305549	test: 0.0337289	best: 0.0337289 (122)	total: 64.8ms	remaining: 462ms
# 123:	learn: 0.0305302	test: 0.0337145	best: 0.0337145 (123)	total: 65.3ms	remaining: 461ms
# 124:	learn: 0.0305059	test: 0.0336987	best: 0.0336987 (124)	total: 65.7ms	remaining: 460ms
# 125:	learn: 0.0304742	test: 0.0336738	best: 0.0336738 (125)	total: 66.1ms	remaining: 459ms
# 126:	learn: 0.0304546	test: 0.0336554	best: 0.0336554 (126)	total: 66.5ms	remaining: 457ms
# 127:	learn: 0.0304349	test: 0.0336393	best: 0.0336393 (127)	total: 66.8ms	remaining: 455ms
# 128:	learn: 0.0304059	test: 0.0336241	best: 0.0336241 (128)	total: 67.2ms	remaining: 453ms
# 129:	learn: 0.0303880	test: 0.0336082	best: 0.0336082 (129)	total: 67.5ms	remaining: 451ms
# 130:	learn: 0.0303684	test: 0.0335971	best: 0.0335971 (130)	total: 67.8ms	remaining: 450ms
# 131:	learn: 0.0303469	test: 0.0335845	best: 0.0335845 (131)	total: 68.1ms	remaining: 448ms
# 132:	learn: 0.0303279	test: 0.0335654	best: 0.0335654 (132)	total: 68.5ms	remaining: 446ms
# 133:	learn: 0.0303091	test: 0.0335449	best: 0.0335449 (133)	total: 69.1ms	remaining: 447ms
# 134:	learn: 0.0302930	test: 0.0335248	best: 0.0335248 (134)	total: 70.3ms	remaining: 451ms
# 135:	learn: 0.0302803	test: 0.0335125	best: 0.0335125 (135)	total: 71.1ms	remaining: 452ms
# 136:	learn: 0.0302658	test: 0.0334999	best: 0.0334999 (136)	total: 71.6ms	remaining: 451ms
# 137:	learn: 0.0302456	test: 0.0334927	best: 0.0334927 (137)	total: 72ms	remaining: 450ms
# 138:	learn: 0.0302335	test: 0.0334805	best: 0.0334805 (138)	total: 72.3ms	remaining: 448ms
# 139:	learn: 0.0302223	test: 0.0334669	best: 0.0334669 (139)	total: 72.6ms	remaining: 446ms
# 140:	learn: 0.0302088	test: 0.0334559	best: 0.0334559 (140)	total: 73.1ms	remaining: 445ms
# 141:	learn: 0.0301970	test: 0.0334390	best: 0.0334390 (141)	total: 73.5ms	remaining: 444ms
# 142:	learn: 0.0301769	test: 0.0334313	best: 0.0334313 (142)	total: 73.9ms	remaining: 443ms
# 143:	learn: 0.0301608	test: 0.0334150	best: 0.0334150 (143)	total: 74.3ms	remaining: 441ms
# 144:	learn: 0.0301466	test: 0.0334024	best: 0.0334024 (144)	total: 74.6ms	remaining: 440ms
# 145:	learn: 0.0301323	test: 0.0333941	best: 0.0333941 (145)	total: 74.9ms	remaining: 438ms
# 146:	learn: 0.0301157	test: 0.0333854	best: 0.0333854 (146)	total: 75.2ms	remaining: 436ms
# 147:	learn: 0.0301010	test: 0.0333679	best: 0.0333679 (147)	total: 75.5ms	remaining: 435ms
# 148:	learn: 0.0300914	test: 0.0333515	best: 0.0333515 (148)	total: 75.8ms	remaining: 433ms
# 149:	learn: 0.0300783	test: 0.0333389	best: 0.0333389 (149)	total: 76.2ms	remaining: 432ms
# 150:	learn: 0.0300662	test: 0.0333228	best: 0.0333228 (150)	total: 76.7ms	remaining: 431ms
# 151:	learn: 0.0300521	test: 0.0333172	best: 0.0333172 (151)	total: 79.1ms	remaining: 441ms
# 152:	learn: 0.0300398	test: 0.0333070	best: 0.0333070 (152)	total: 79.4ms	remaining: 440ms
# 153:	learn: 0.0300213	test: 0.0332959	best: 0.0332959 (153)	total: 79.7ms	remaining: 438ms
# 154:	learn: 0.0300113	test: 0.0332792	best: 0.0332792 (154)	total: 80.2ms	remaining: 437ms
# 155:	learn: 0.0299965	test: 0.0332820	best: 0.0332792 (154)	total: 80.6ms	remaining: 436ms
# 156:	learn: 0.0299869	test: 0.0332720	best: 0.0332720 (156)	total: 80.9ms	remaining: 435ms
# 157:	learn: 0.0299772	test: 0.0332697	best: 0.0332697 (157)	total: 81.3ms	remaining: 433ms
# 158:	learn: 0.0299620	test: 0.0332594	best: 0.0332594 (158)	total: 81.5ms	remaining: 431ms
# 159:	learn: 0.0299519	test: 0.0332506	best: 0.0332506 (159)	total: 81.9ms	remaining: 430ms
# 160:	learn: 0.0299427	test: 0.0332535	best: 0.0332506 (159)	total: 82.2ms	remaining: 428ms
# 161:	learn: 0.0299277	test: 0.0332567	best: 0.0332506 (159)	total: 82.5ms	remaining: 427ms
# 162:	learn: 0.0299154	test: 0.0332471	best: 0.0332471 (162)	total: 82.8ms	remaining: 425ms
# 163:	learn: 0.0299025	test: 0.0332468	best: 0.0332468 (163)	total: 83.1ms	remaining: 424ms
# 164:	learn: 0.0298903	test: 0.0332353	best: 0.0332353 (164)	total: 83.4ms	remaining: 422ms
# 165:	learn: 0.0298752	test: 0.0332294	best: 0.0332294 (165)	total: 83.8ms	remaining: 421ms
# 166:	learn: 0.0298664	test: 0.0332253	best: 0.0332253 (166)	total: 84.3ms	remaining: 420ms
# 167:	learn: 0.0298562	test: 0.0332149	best: 0.0332149 (167)	total: 84.8ms	remaining: 420ms
# 168:	learn: 0.0298455	test: 0.0332097	best: 0.0332097 (168)	total: 86.2ms	remaining: 424ms
# 169:	learn: 0.0298323	test: 0.0332015	best: 0.0332015 (169)	total: 87.3ms	remaining: 426ms
# 170:	learn: 0.0298235	test: 0.0331972	best: 0.0331972 (170)	total: 87.7ms	remaining: 425ms
# 171:	learn: 0.0298115	test: 0.0331930	best: 0.0331930 (171)	total: 88ms	remaining: 424ms
# 172:	learn: 0.0297987	test: 0.0331840	best: 0.0331840 (172)	total: 88.3ms	remaining: 422ms
# 173:	learn: 0.0297921	test: 0.0331820	best: 0.0331820 (173)	total: 88.6ms	remaining: 421ms
# 174:	learn: 0.0297780	test: 0.0331788	best: 0.0331788 (174)	total: 89ms	remaining: 420ms
# 175:	learn: 0.0297691	test: 0.0331720	best: 0.0331720 (175)	total: 89.4ms	remaining: 419ms
# ...
# 697:	learn: 0.0255660	total: 286ms	remaining: 124ms
# 698:	learn: 0.0255575	total: 287ms	remaining: 123ms
# 699:	learn: 0.0255514	total: 287ms	remaining: 123ms
# 700:	learn: 0.0255450	total: 287ms	remaining: 123ms
# 701:	learn: 0.0255387	total: 288ms	remaining: 122ms
# 702:	learn: 0.0255371	total: 288ms	remaining: 122ms
# 703:	learn: 0.0255270	total: 289ms	remaining: 121ms
# 704:	learn: 0.0255255	total: 289ms	remaining: 121ms
# 705:	learn: 0.0255214	total: 289ms	remaining: 120ms
# 706:	learn: 0.0255153	total: 290ms	remaining: 120ms
# 707:	learn: 0.0255090	total: 290ms	remaining: 120ms
# 708:	learn: 0.0255039	total: 290ms	remaining: 119ms
# 709:	learn: 0.0254954	total: 291ms	remaining: 119ms
# 710:	learn: 0.0254890	total: 291ms	remaining: 118ms
# 711:	learn: 0.0254843	total: 292ms	remaining: 118ms
# 712:	learn: 0.0254771	total: 292ms	remaining: 118ms
# 713:	learn: 0.0254733	total: 293ms	remaining: 117ms
# 714:	learn: 0.0254727	total: 293ms	remaining: 117ms
# 715:	learn: 0.0254664	total: 293ms	remaining: 116ms
# 716:	learn: 0.0254655	total: 294ms	remaining: 116ms
# 717:	learn: 0.0254599	total: 294ms	remaining: 115ms
# 718:	learn: 0.0254553	total: 295ms	remaining: 115ms
# 719:	learn: 0.0254513	total: 295ms	remaining: 115ms
# 720:	learn: 0.0254435	total: 295ms	remaining: 114ms
# 721:	learn: 0.0254416	total: 296ms	remaining: 114ms
# 722:	learn: 0.0254384	total: 296ms	remaining: 113ms
# 723:	learn: 0.0254303	total: 296ms	remaining: 113ms
# 724:	learn: 0.0254224	total: 297ms	remaining: 112ms
# 725:	learn: 0.0254150	total: 297ms	remaining: 112ms
# 726:	learn: 0.0254096	total: 297ms	remaining: 112ms
# 727:	learn: 0.0254017	total: 298ms	remaining: 111ms
# 728:	learn: 0.0253991	total: 298ms	remaining: 111ms
# 729:	learn: 0.0253956	total: 298ms	remaining: 110ms
# 730:	learn: 0.0253920	total: 299ms	remaining: 110ms
# 731:	learn: 0.0253849	total: 299ms	remaining: 110ms
# 732:	learn: 0.0253786	total: 300ms	remaining: 109ms
# 733:	learn: 0.0253775	total: 300ms	remaining: 109ms
# 734:	learn: 0.0253696	total: 300ms	remaining: 108ms
# 735:	learn: 0.0253670	total: 301ms	remaining: 108ms
# 736:	learn: 0.0253609	total: 301ms	remaining: 107ms
# 737:	learn: 0.0253586	total: 301ms	remaining: 107ms
# 738:	learn: 0.0253525	total: 302ms	remaining: 107ms
# 739:	learn: 0.0253492	total: 302ms	remaining: 106ms
# 740:	learn: 0.0253433	total: 303ms	remaining: 106ms
# 741:	learn: 0.0253342	total: 303ms	remaining: 105ms
# 742:	learn: 0.0253298	total: 303ms	remaining: 105ms
# 743:	learn: 0.0253235	total: 304ms	remaining: 105ms
# 744:	learn: 0.0253218	total: 304ms	remaining: 104ms
# 745:	learn: 0.0253158	total: 305ms	remaining: 104ms
# 746:	learn: 0.0253147	total: 305ms	remaining: 103ms
# 747:	learn: 0.0253118	total: 305ms	remaining: 103ms
# 748:	learn: 0.0253105	total: 306ms	remaining: 102ms
# 749:	learn: 0.0253052	total: 306ms	remaining: 102ms
# 750:	learn: 0.0253001	total: 306ms	remaining: 102ms
# 751:	learn: 0.0252977	total: 307ms	remaining: 101ms
# 752:	learn: 0.0252860	total: 307ms	remaining: 101ms
# 753:	learn: 0.0252813	total: 307ms	remaining: 100ms
# 754:	learn: 0.0252737	total: 308ms	remaining: 99.8ms
# 755:	learn: 0.0252683	total: 308ms	remaining: 99.4ms
# 756:	learn: 0.0252608	total: 308ms	remaining: 99ms
# 757:	learn: 0.0252603	total: 309ms	remaining: 98.6ms
# 758:	learn: 0.0252533	total: 309ms	remaining: 98.2ms
# 759:	learn: 0.0252527	total: 310ms	remaining: 97.9ms
# 760:	learn: 0.0252481	total: 310ms	remaining: 97.4ms
# 761:	learn: 0.0252454	total: 311ms	remaining: 97ms
# 762:	learn: 0.0252449	total: 311ms	remaining: 96.6ms
# 763:	learn: 0.0252398	total: 311ms	remaining: 96.2ms
# 764:	learn: 0.0252309	total: 312ms	remaining: 95.7ms
# 765:	learn: 0.0252259	total: 312ms	remaining: 95.3ms
# 766:	learn: 0.0252200	total: 313ms	remaining: 94.9ms
# 767:	learn: 0.0252131	total: 313ms	remaining: 94.5ms
# 768:	learn: 0.0252069	total: 313ms	remaining: 94.1ms
# 769:	learn: 0.0252002	total: 314ms	remaining: 93.7ms
# 770:	learn: 0.0251949	total: 314ms	remaining: 93.2ms
# 771:	learn: 0.0251876	total: 314ms	remaining: 92.8ms
# 772:	learn: 0.0251821	total: 315ms	remaining: 92.4ms
# 773:	learn: 0.0251766	total: 315ms	remaining: 92ms
# 774:	learn: 0.0251731	total: 315ms	remaining: 91.6ms
# 775:	learn: 0.0251701	total: 316ms	remaining: 91.2ms
# 776:	learn: 0.0251669	total: 316ms	remaining: 90.8ms
# 777:	learn: 0.0251577	total: 317ms	remaining: 90.3ms
# 778:	learn: 0.0251540	total: 317ms	remaining: 89.9ms
# 779:	learn: 0.0251516	total: 318ms	remaining: 89.6ms
# 780:	learn: 0.0251427	total: 318ms	remaining: 89.2ms
# 781:	learn: 0.0251360	total: 318ms	remaining: 88.8ms
# 782:	learn: 0.0251295	total: 319ms	remaining: 88.4ms
# 783:	learn: 0.0251242	total: 319ms	remaining: 87.9ms
# 784:	learn: 0.0251214	total: 320ms	remaining: 87.5ms
# 785:	learn: 0.0251169	total: 320ms	remaining: 87.1ms
# 786:	learn: 0.0251104	total: 320ms	remaining: 86.7ms
# 787:	learn: 0.0251013	total: 321ms	remaining: 86.3ms
# 788:	learn: 0.0250979	total: 321ms	remaining: 85.9ms
# 789:	learn: 0.0250932	total: 321ms	remaining: 85.4ms
# 790:	learn: 0.0250860	total: 322ms	remaining: 85.1ms
# 791:	learn: 0.0250842	total: 322ms	remaining: 84.7ms
# 792:	learn: 0.0250816	total: 323ms	remaining: 84.2ms
# 793:	learn: 0.0250784	total: 323ms	remaining: 83.8ms
# 794:	learn: 0.0250779	total: 323ms	remaining: 83.4ms
# 795:	learn: 0.0250715	total: 324ms	remaining: 83ms
# 796:	learn: 0.0250659	total: 324ms	remaining: 82.5ms
# 797:	learn: 0.0250633	total: 324ms	remaining: 82.1ms
# 798:	learn: 0.0250587	total: 325ms	remaining: 81.7ms
# 799:	learn: 0.0250543	total: 325ms	remaining: 81.3ms
# 800:	learn: 0.0250515	total: 326ms	remaining: 80.9ms
# 801:	learn: 0.0250442	total: 326ms	remaining: 80.5ms
# 802:	learn: 0.0250390	total: 326ms	remaining: 80.1ms
# 803:	learn: 0.0250340	total: 327ms	remaining: 79.6ms
# 804:	learn: 0.0250322	total: 327ms	remaining: 79.2ms
# 805:	learn: 0.0250260	total: 327ms	remaining: 78.8ms
# 806:	learn: 0.0250216	total: 328ms	remaining: 78.4ms
# 807:	learn: 0.0250211	total: 328ms	remaining: 78ms
# 808:	learn: 0.0250199	total: 329ms	remaining: 77.6ms
# 809:	learn: 0.0250108	total: 329ms	remaining: 77.1ms
# 810:	learn: 0.0250060	total: 329ms	remaining: 76.7ms
# 811:	learn: 0.0249959	total: 329ms	remaining: 76.3ms
# 812:	learn: 0.0249904	total: 330ms	remaining: 75.9ms
# 813:	learn: 0.0249858	total: 330ms	remaining: 75.5ms
# 814:	learn: 0.0249799	total: 331ms	remaining: 75.1ms
# 815:	learn: 0.0249720	total: 331ms	remaining: 74.7ms
# 816:	learn: 0.0249665	total: 332ms	remaining: 74.3ms
# 817:	learn: 0.0249622	total: 332ms	remaining: 73.9ms
# 818:	learn: 0.0249545	total: 332ms	remaining: 73.5ms
# 819:	learn: 0.0249430	total: 333ms	remaining: 73.1ms
# 820:	learn: 0.0249359	total: 333ms	remaining: 72.7ms
# 821:	learn: 0.0249302	total: 334ms	remaining: 72.3ms
# 822:	learn: 0.0249265	total: 334ms	remaining: 71.9ms
# 823:	learn: 0.0249255	total: 335ms	remaining: 71.4ms
# 824:	learn: 0.0249191	total: 335ms	remaining: 71ms
# 825:	learn: 0.0249174	total: 335ms	remaining: 70.6ms
# 826:	learn: 0.0249109	total: 336ms	remaining: 70.2ms
# 827:	learn: 0.0249028	total: 336ms	remaining: 69.8ms
# 828:	learn: 0.0248967	total: 336ms	remaining: 69.4ms
# 829:	learn: 0.0248919	total: 337ms	remaining: 68.9ms
# 830:	learn: 0.0248855	total: 337ms	remaining: 68.6ms
# 831:	learn: 0.0248846	total: 337ms	remaining: 68.1ms
# 832:	learn: 0.0248830	total: 338ms	remaining: 67.7ms
# 833:	learn: 0.0248761	total: 338ms	remaining: 67.3ms
# 834:	learn: 0.0248672	total: 339ms	remaining: 66.9ms
# 835:	learn: 0.0248648	total: 339ms	remaining: 66.5ms
# 836:	learn: 0.0248617	total: 339ms	remaining: 66.1ms
# 837:	learn: 0.0248563	total: 340ms	remaining: 65.7ms
# 838:	learn: 0.0248549	total: 340ms	remaining: 65.3ms
# 839:	learn: 0.0248535	total: 341ms	remaining: 64.9ms
# 840:	learn: 0.0248483	total: 341ms	remaining: 64.5ms
# 841:	learn: 0.0248455	total: 341ms	remaining: 64.1ms
# 842:	learn: 0.0248390	total: 342ms	remaining: 63.6ms
# 843:	learn: 0.0248363	total: 342ms	remaining: 63.2ms
# 844:	learn: 0.0248313	total: 342ms	remaining: 62.8ms
# 845:	learn: 0.0248271	total: 343ms	remaining: 62.4ms
# 846:	learn: 0.0248216	total: 343ms	remaining: 62ms
# 847:	learn: 0.0248162	total: 344ms	remaining: 61.6ms
# 848:	learn: 0.0248119	total: 344ms	remaining: 61.2ms
# 849:	learn: 0.0248054	total: 344ms	remaining: 60.8ms
# 850:	learn: 0.0247998	total: 345ms	remaining: 60.4ms
# 851:	learn: 0.0247984	total: 345ms	remaining: 59.9ms
# 852:	learn: 0.0247948	total: 345ms	remaining: 59.5ms
# 853:	learn: 0.0247945	total: 346ms	remaining: 59.1ms
# 854:	learn: 0.0247903	total: 346ms	remaining: 58.7ms
# 855:	learn: 0.0247809	total: 347ms	remaining: 58.4ms
# 856:	learn: 0.0247715	total: 348ms	remaining: 58ms
# 857:	learn: 0.0247665	total: 348ms	remaining: 57.6ms
# 858:	learn: 0.0247600	total: 348ms	remaining: 57.2ms
# 859:	learn: 0.0247535	total: 349ms	remaining: 56.8ms
# 860:	learn: 0.0247470	total: 349ms	remaining: 56.4ms
# 861:	learn: 0.0247419	total: 350ms	remaining: 56ms
# 862:	learn: 0.0247364	total: 350ms	remaining: 55.6ms
# 863:	learn: 0.0247277	total: 351ms	remaining: 55.2ms
# 864:	learn: 0.0247242	total: 351ms	remaining: 54.8ms
# 865:	learn: 0.0247187	total: 351ms	remaining: 54.4ms
# 866:	learn: 0.0247145	total: 352ms	remaining: 54ms
# 867:	learn: 0.0247083	total: 352ms	remaining: 53.5ms
# 868:	learn: 0.0247001	total: 352ms	remaining: 53.1ms
# 869:	learn: 0.0246955	total: 353ms	remaining: 52.7ms
# 870:	learn: 0.0246882	total: 353ms	remaining: 52.3ms
# 871:	learn: 0.0246818	total: 354ms	remaining: 51.9ms
# 872:	learn: 0.0246768	total: 354ms	remaining: 51.5ms
# 873:	learn: 0.0246726	total: 354ms	remaining: 51.1ms
# 874:	learn: 0.0246650	total: 355ms	remaining: 50.7ms
# 875:	learn: 0.0246613	total: 355ms	remaining: 50.3ms
# 876:	learn: 0.0246537	total: 355ms	remaining: 49.9ms
# 877:	learn: 0.0246443	total: 356ms	remaining: 49.5ms
# 878:	learn: 0.0246409	total: 357ms	remaining: 49.1ms
# 879:	learn: 0.0246367	total: 357ms	remaining: 48.7ms
# 880:	learn: 0.0246353	total: 357ms	remaining: 48.2ms
# 881:	learn: 0.0246308	total: 357ms	remaining: 47.8ms
# 882:	learn: 0.0246248	total: 358ms	remaining: 47.4ms
# 883:	learn: 0.0246210	total: 359ms	remaining: 47.1ms
# 884:	learn: 0.0246163	total: 359ms	remaining: 46.7ms
# 885:	learn: 0.0246093	total: 360ms	remaining: 46.3ms
# 886:	learn: 0.0246036	total: 360ms	remaining: 45.9ms
# 887:	learn: 0.0246021	total: 361ms	remaining: 45.5ms
# 888:	learn: 0.0245937	total: 361ms	remaining: 45.1ms
# 889:	learn: 0.0245881	total: 361ms	remaining: 44.7ms
# 890:	learn: 0.0245816	total: 362ms	remaining: 44.3ms
# 891:	learn: 0.0245751	total: 362ms	remaining: 43.9ms
# 892:	learn: 0.0245704	total: 363ms	remaining: 43.5ms
# 893:	learn: 0.0245640	total: 363ms	remaining: 43ms
# 894:	learn: 0.0245602	total: 363ms	remaining: 42.6ms
# 895:	learn: 0.0245592	total: 364ms	remaining: 42.2ms
# 896:	learn: 0.0245534	total: 364ms	remaining: 41.8ms
# 897:	learn: 0.0245518	total: 365ms	remaining: 41.4ms
# 898:	learn: 0.0245447	total: 365ms	remaining: 41ms
# 899:	learn: 0.0245397	total: 365ms	remaining: 40.6ms
# 900:	learn: 0.0245352	total: 366ms	remaining: 40.2ms
# 901:	learn: 0.0245271	total: 366ms	remaining: 39.8ms
# 902:	learn: 0.0245219	total: 367ms	remaining: 39.4ms
# 903:	learn: 0.0245161	total: 367ms	remaining: 39ms
# 904:	learn: 0.0245111	total: 367ms	remaining: 38.6ms
# 905:	learn: 0.0245051	total: 368ms	remaining: 38.1ms
# 906:	learn: 0.0245000	total: 368ms	remaining: 37.7ms
# 907:	learn: 0.0244975	total: 368ms	remaining: 37.3ms
# 908:	learn: 0.0244908	total: 369ms	remaining: 36.9ms
# 909:	learn: 0.0244841	total: 369ms	remaining: 36.5ms
# 910:	learn: 0.0244815	total: 369ms	remaining: 36.1ms
# 911:	learn: 0.0244764	total: 370ms	remaining: 35.7ms
# 912:	learn: 0.0244721	total: 370ms	remaining: 35.3ms
# 913:	learn: 0.0244652	total: 371ms	remaining: 34.9ms
# 914:	learn: 0.0244628	total: 371ms	remaining: 34.5ms
# 915:	learn: 0.0244604	total: 372ms	remaining: 34.1ms
# 916:	learn: 0.0244590	total: 372ms	remaining: 33.7ms
# 917:	learn: 0.0244544	total: 372ms	remaining: 33.3ms
# 918:	learn: 0.0244526	total: 373ms	remaining: 32.9ms
# 919:	learn: 0.0244473	total: 373ms	remaining: 32.5ms
# 920:	learn: 0.0244421	total: 374ms	remaining: 32ms
# 921:	learn: 0.0244385	total: 374ms	remaining: 31.6ms
# 922:	learn: 0.0244301	total: 375ms	remaining: 31.2ms
# 923:	learn: 0.0244241	total: 375ms	remaining: 30.8ms
# 924:	learn: 0.0244162	total: 375ms	remaining: 30.4ms
# 925:	learn: 0.0244101	total: 376ms	remaining: 30ms
# 926:	learn: 0.0244060	total: 376ms	remaining: 29.6ms
# 927:	learn: 0.0244026	total: 377ms	remaining: 29.2ms
# 928:	learn: 0.0243963	total: 377ms	remaining: 28.8ms
# 929:	learn: 0.0243910	total: 377ms	remaining: 28.4ms
# 930:	learn: 0.0243824	total: 378ms	remaining: 28ms
# 931:	learn: 0.0243795	total: 378ms	remaining: 27.6ms
# 932:	learn: 0.0243781	total: 379ms	remaining: 27.2ms
# 933:	learn: 0.0243761	total: 379ms	remaining: 26.8ms
# 934:	learn: 0.0243742	total: 379ms	remaining: 26.4ms
# 935:	learn: 0.0243689	total: 380ms	remaining: 26ms
# 936:	learn: 0.0243684	total: 380ms	remaining: 25.6ms
# 937:	learn: 0.0243614	total: 380ms	remaining: 25.1ms
# 938:	learn: 0.0243579	total: 381ms	remaining: 24.7ms
# 939:	learn: 0.0243568	total: 381ms	remaining: 24.3ms
# 940:	learn: 0.0243550	total: 382ms	remaining: 23.9ms
# 941:	learn: 0.0243525	total: 382ms	remaining: 23.5ms
# 942:	learn: 0.0243473	total: 382ms	remaining: 23.1ms
# 943:	learn: 0.0243422	total: 383ms	remaining: 22.7ms
# 944:	learn: 0.0243379	total: 383ms	remaining: 22.3ms
# 945:	learn: 0.0243372	total: 384ms	remaining: 21.9ms
# 946:	learn: 0.0243286	total: 384ms	remaining: 21.5ms
# 947:	learn: 0.0243231	total: 384ms	remaining: 21.1ms
# 948:	learn: 0.0243165	total: 385ms	remaining: 20.7ms
# 949:	learn: 0.0243112	total: 385ms	remaining: 20.3ms
# 950:	learn: 0.0243067	total: 386ms	remaining: 19.9ms
# 951:	learn: 0.0243008	total: 386ms	remaining: 19.5ms
# 952:	learn: 0.0242976	total: 386ms	remaining: 19.1ms
# 953:	learn: 0.0242932	total: 387ms	remaining: 18.6ms
# 954:	learn: 0.0242857	total: 387ms	remaining: 18.2ms
# 955:	learn: 0.0242825	total: 387ms	remaining: 17.8ms
# 956:	learn: 0.0242808	total: 388ms	remaining: 17.4ms
# 957:	learn: 0.0242754	total: 388ms	remaining: 17ms
# 958:	learn: 0.0242697	total: 388ms	remaining: 16.6ms
# 959:	learn: 0.0242600	total: 389ms	remaining: 16.2ms
# 960:	learn: 0.0242531	total: 389ms	remaining: 15.8ms
# 961:	learn: 0.0242468	total: 390ms	remaining: 15.4ms
# 962:	learn: 0.0242424	total: 390ms	remaining: 15ms
# 963:	learn: 0.0242406	total: 390ms	remaining: 14.6ms
# 964:	learn: 0.0242374	total: 391ms	remaining: 14.2ms
# 965:	learn: 0.0242327	total: 391ms	remaining: 13.8ms
# 966:	learn: 0.0242305	total: 391ms	remaining: 13.4ms
# 967:	learn: 0.0242252	total: 392ms	remaining: 13ms
# 968:	learn: 0.0242210	total: 392ms	remaining: 12.5ms
# 969:	learn: 0.0242171	total: 393ms	remaining: 12.2ms
# 970:	learn: 0.0242131	total: 393ms	remaining: 11.7ms
# 971:	learn: 0.0242096	total: 394ms	remaining: 11.3ms
# 972:	learn: 0.0242073	total: 394ms	remaining: 10.9ms
# 973:	learn: 0.0242026	total: 394ms	remaining: 10.5ms
# 974:	learn: 0.0241982	total: 395ms	remaining: 10.1ms
# 975:	learn: 0.0241942	total: 395ms	remaining: 9.72ms
# 976:	learn: 0.0241920	total: 395ms	remaining: 9.31ms
# 977:	learn: 0.0241838	total: 396ms	remaining: 8.9ms
# 978:	learn: 0.0241778	total: 396ms	remaining: 8.5ms
# 979:	learn: 0.0241726	total: 397ms	remaining: 8.09ms
# 980:	learn: 0.0241668	total: 397ms	remaining: 7.68ms
# 981:	learn: 0.0241619	total: 397ms	remaining: 7.28ms
# 982:	learn: 0.0241584	total: 397ms	remaining: 6.87ms
# 983:	learn: 0.0241554	total: 398ms	remaining: 6.47ms
# 984:	learn: 0.0241506	total: 398ms	remaining: 6.06ms
# 985:	learn: 0.0241461	total: 398ms	remaining: 5.66ms
# 986:	learn: 0.0241412	total: 399ms	remaining: 5.25ms
# 987:	learn: 0.0241370	total: 399ms	remaining: 4.85ms
# 988:	learn: 0.0241349	total: 399ms	remaining: 4.44ms
# 989:	learn: 0.0241301	total: 400ms	remaining: 4.04ms
# 990:	learn: 0.0241296	total: 400ms	remaining: 3.63ms
# 991:	learn: 0.0241278	total: 401ms	remaining: 3.23ms
# 992:	learn: 0.0241245	total: 401ms	remaining: 2.83ms
# 993:	learn: 0.0241216	total: 401ms	remaining: 2.42ms
# 994:	learn: 0.0241202	total: 402ms	remaining: 2.02ms
# 995:	learn: 0.0241172	total: 402ms	remaining: 1.61ms
# 996:	learn: 0.0241134	total: 403ms	remaining: 1.21ms
# 997:	learn: 0.0241051	total: 403ms	remaining: 807us
# 998:	learn: 0.0241034	total: 403ms	remaining: 403us
# 999:	learn: 0.0240970	total: 404ms	remaining: 0us

# %%
catboost_preds = catboost_results[1].predict(X_test_scaled)

# %%
np.sqrt(mean_squared_error(y_test, catboost_preds)), mean_absolute_error(y_test, catboost_preds)
# Out:
# (0.04608289668388523, 0.03651715887540573)
